# %%
import numpy as np
#Iris Datensatz mit p = 1.0

# load all datasets
# %store -r Iris
print("Iris Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 1.0
p = 1.0
print("p = 1.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Iris_v1_5 = compute_random_evaluations_probabilities(Iris.X, m=5, p=p, rng=rng)
data_Iris_v1_10 = compute_random_evaluations_probabilities(Iris.X, m=10, p=p, rng=rng)
data_Iris_v1_50 = compute_random_evaluations_probabilities(Iris.X, m=50, p=p, rng=rng)
data_Iris_v1_100 = compute_random_evaluations_probabilities(Iris.X, m=100, p=p, rng=rng)
data_Iris_v1_200 = compute_random_evaluations_probabilities(Iris.X, m=200, p=p, rng=rng)
data_Iris_v1_500 = compute_random_evaluations_probabilities(Iris.X, m=500, p=p, rng=rng)
data_Iris_v1_1000 = compute_random_evaluations_probabilities(Iris.X, m=1000, p=p, rng=rng)
data_Iris_v1_10000 = compute_random_evaluations_probabilities(Iris.X, m=10000, p=p, rng=rng)
data_Iris_v1_100000 = compute_random_evaluations_probabilities(Iris.X, m=100000, p=p, rng=rng)

data_Iris_v1_Vergleich_5_10 = np.maximum(data_Iris_v1_5/data_Iris_v1_10, data_Iris_v1_10/data_Iris_v1_5)
data_Iris_v1_Vergleich_10_50 = np.maximum(data_Iris_v1_10/data_Iris_v1_50, data_Iris_v1_50/data_Iris_v1_10)
data_Iris_v1_Vergleich_50_100 = np.maximum(data_Iris_v1_50/data_Iris_v1_100, data_Iris_v1_100/data_Iris_v1_50)
data_Iris_v1_Vergleich_100_200 = np.maximum(data_Iris_v1_100/data_Iris_v1_200, data_Iris_v1_200/data_Iris_v1_100)
data_Iris_v1_Vergleich_200_500 = np.maximum(data_Iris_v1_200/data_Iris_v1_500, data_Iris_v1_500/data_Iris_v1_200)
data_Iris_v1_Vergleich_500_1000 = np.maximum(data_Iris_v1_500/data_Iris_v1_1000, data_Iris_v1_1000/data_Iris_v1_500)
data_Iris_v1_Vergleich_1000_10000 = np.maximum(data_Iris_v1_1000/data_Iris_v1_10000, data_Iris_v1_10000/data_Iris_v1_1000)

print("Vergleich m=5 und m=10")
print(max(data_Iris_v1_Vergleich_5_10))
print("Vergleich m=10 und m=50")
print(max(data_Iris_v1_Vergleich_10_50))
print("Vergleich m=50 und m=100")
print(max(data_Iris_v1_Vergleich_50_100))
print("Vergleich m=100 und m=200")
print(max(data_Iris_v1_Vergleich_100_200))
print("Vergleich m=200 und m=500")
print(max(data_Iris_v1_Vergleich_200_500))
print("Vergleich m=500 und m=1000")
print(max(data_Iris_v1_Vergleich_500_1000))
print("Vergleich m=1000 und m=10000")
print(max(data_Iris_v1_Vergleich_1000_10000))
# Out:
# Iris Datensatz
# p = 1.0
# Version 1
# Vergleich m=5 und m=10
# 1.7594946712502382
# Vergleich m=10 und m=50
# 2.064860529945912
# Vergleich m=50 und m=100
# 1.291073299885802
# Vergleich m=100 und m=200
# 1.1429055210134647
# Vergleich m=200 und m=500
# 1.1403427466597391
# Vergleich m=500 und m=1000
# 1.0801343817176148
# Vergleich m=1000 und m=10000
# 1.0368618820806874
