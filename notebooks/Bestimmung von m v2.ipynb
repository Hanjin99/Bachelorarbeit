# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Example2D Datensatz
# %store -r Example2D
print("Example2D Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Example2D_5 = compute_random_evaluations_probabilities_v2(Example2D.X, m=5, p=i, rng=rng)
    data_Example2D_10 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10, p=i, rng=rng)
    data_Example2D_50 = compute_random_evaluations_probabilities_v2(Example2D.X, m=50, p=i, rng=rng)
    data_Example2D_100 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100, p=i, rng=rng)
    data_Example2D_200 = compute_random_evaluations_probabilities_v2(Example2D.X, m=200, p=i, rng=rng)
    data_Example2D_500 = compute_random_evaluations_probabilities_v2(Example2D.X, m=500, p=i, rng=rng)
    data_Example2D_1000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1000, p=i, rng=rng)
    data_Example2D_10000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10000, p=i, rng=rng)
    data_Example2D_100000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100000, p=i, rng=rng)
    
    data_Example2D_Vergleich_5_10 = np.maximum(data_Example2D_5/data_Example2D_10, data_Example2D_10/data_Example2D_5)
    data_Example2D_Vergleich_10_50 = np.maximum(data_Example2D_10/data_Example2D_50, data_Example2D_50/data_Example2D_10)
    data_Example2D_Vergleich_50_100 = np.maximum(data_Example2D_50/data_Example2D_100, data_Example2D_100/data_Example2D_50)
    data_Example2D_Vergleich_100_200 = np.maximum(data_Example2D_100/data_Example2D_200, data_Example2D_200/data_Example2D_100)
    data_Example2D_Vergleich_200_500 = np.maximum(data_Example2D_200/data_Example2D_500, data_Example2D_500/data_Example2D_200)
    data_Example2D_Vergleich_500_1000 = np.maximum(data_Example2D_500/data_Example2D_1000, data_Example2D_1000/data_Example2D_500)
    data_Example2D_Vergleich_1000_10000 = np.maximum(data_Example2D_1000/data_Example2D_10000, data_Example2D_10000/data_Example2D_1000)
    data_Example2D_Vergleich_10000_100000 = np.maximum(data_Example2D_10000/data_Example2D_100000, data_Example2D_100000/data_Example2D_10000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Example2D_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Example2D_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Example2D_Vergleich_50_100))
    print("Vergleich m=100 und m=200")
    print(max(data_Example2D_Vergleich_100_200))
    print("Vergleich m=200 und m=500")
    print(max(data_Example2D_Vergleich_200_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Example2D_Vergleich_500_1000))
    print("Vergleich m=1000 und m=10000")
    print(max(data_Example2D_Vergleich_1000_10000))
    print("Vergleich m=10000 und m=100000")
    print(max(data_Example2D_Vergleich_10000_100000))
    print("")
# Out:
# Iris Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 2.2088239070221194
# Vergleich m=10 und m=50
# 2.4766759326210903
# Vergleich m=50 und m=100
# 1.596084699516401
# Vergleich m=100 und m=200
# 1.151180825510802
# Vergleich m=200 und m=500
# 1.149497384784562
# Vergleich m=500 und m=1000
# 1.0740908334872643
# Vergleich m=1000 und m=10000
# 1.0398310699942064
# Vergleich m=10000 und m=100000
# 1.0111652237907762
#
# p =  1.3
# Vergleich m=5 und m=10
# 2.837233403830839
# Vergleich m=10 und m=50
# 3.1362182860150076
# Vergleich m=50 und m=100
# 1.8652879712252892
# Vergleich m=100 und m=200
# 1.1987234122433605
# Vergleich m=200 und m=500
# 1.203775990533049
# Vergleich m=500 und m=1000
# 1.0933686368703792
# Vergleich m=1000 und m=10000
# 1.048982723228246
# Vergleich m=10000 und m=100000
# 1.0135017846258632
#
# p =  1.5
# Vergleich m=5 und m=10
# 3.4209976460221645
# Vergleich m=10 und m=50
# 3.6504672608493816
# Vergleich m=50 und m=100
# 2.065558132278344
# Vergleich m=100 und m=200
# 1.2321892369566558
# Vergleich m=200 und m=500
# 1.2422651279794032
# Vergleich m=500 und m=1000
# 1.110467053615838
# Vergleich m=1000 und m=10000
# 1.0546274383201968
# Vergleich m=10000 und m=100000
# 1.0150815425924302
#
# p =  1.7
# Vergleich m=5 und m=10
# 4.140099248869755
# Vergleich m=10 und m=50
# 4.233714711647184
# Vergleich m=50 und m=100
# 2.283856040649381
# Vergleich m=100 und m=200
# 1.274090853383805
# Vergleich m=200 und m=500
# 1.2815364024404907
# Vergleich m=500 und m=1000
# 1.128422155754332
# Vergleich m=1000 und m=10000
# 1.0602785386032172
# Vergleich m=10000 und m=100000
# 1.018259138158076
#
# p =  2.0
# Vergleich m=5 und m=10
# 5.54381628562855
# Vergleich m=10 und m=50
# 5.255622136936041
# Vergleich m=50 und m=100
# 2.649360374405058
# Vergleich m=100 und m=200
# 1.337434659815885
# Vergleich m=200 und m=500
# 1.3399403171825806
# Vergleich m=500 und m=1000
# 1.1565407498120004
# Vergleich m=1000 und m=10000
# 1.0713367619162781
# Vergleich m=10000 und m=100000
# 1.0238106066776278

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Example2D Datensatz
# %store -r Example2D
print("Example2D Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Example2D_5 = compute_random_evaluations_probabilities_v2(Example2D.X, m=5, p=i, rng=rng)
    data_Example2D_10 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10, p=i, rng=rng)
    data_Example2D_50 = compute_random_evaluations_probabilities_v2(Example2D.X, m=50, p=i, rng=rng)
    data_Example2D_100 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100, p=i, rng=rng)
    data_Example2D_200 = compute_random_evaluations_probabilities_v2(Example2D.X, m=200, p=i, rng=rng)
    data_Example2D_500 = compute_random_evaluations_probabilities_v2(Example2D.X, m=500, p=i, rng=rng)
    data_Example2D_1000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1000, p=i, rng=rng)
    data_Example2D_10000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10000, p=i, rng=rng)
    data_Example2D_100000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100000, p=i, rng=rng)
    
    data_Example2D_Vergleich_5_10 = np.maximum(data_Example2D_5/data_Example2D_10, data_Example2D_10/data_Example2D_5)
    data_Example2D_Vergleich_10_50 = np.maximum(data_Example2D_10/data_Example2D_50, data_Example2D_50/data_Example2D_10)
    data_Example2D_Vergleich_50_100 = np.maximum(data_Example2D_50/data_Example2D_100, data_Example2D_100/data_Example2D_50)
    data_Example2D_Vergleich_100_200 = np.maximum(data_Example2D_100/data_Example2D_200, data_Example2D_200/data_Example2D_100)
    data_Example2D_Vergleich_200_500 = np.maximum(data_Example2D_200/data_Example2D_500, data_Example2D_500/data_Example2D_200)
    data_Example2D_Vergleich_500_1000 = np.maximum(data_Example2D_500/data_Example2D_1000, data_Example2D_1000/data_Example2D_500)
    data_Example2D_Vergleich_1000_10000 = np.maximum(data_Example2D_1000/data_Example2D_10000, data_Example2D_10000/data_Example2D_1000)
    data_Example2D_Vergleich_10000_100000 = np.maximum(data_Example2D_10000/data_Example2D_100000, data_Example2D_100000/data_Example2D_10000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Example2D_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Example2D_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Example2D_Vergleich_50_100))
    print("Vergleich m=100 und m=200")
    print(max(data_Example2D_Vergleich_100_200))
    print("Vergleich m=200 und m=500")
    print(max(data_Example2D_Vergleich_200_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Example2D_Vergleich_500_1000))
    print("Vergleich m=1000 und m=10000")
    print(max(data_Example2D_Vergleich_1000_10000))
    print("Vergleich m=10000 und m=100000")
    print(max(data_Example2D_Vergleich_10000_100000))
    print("")
# Out:
# Example2D Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 14.774737422371313
# Vergleich m=10 und m=50
# 1.612262802391592
# Vergleich m=50 und m=100
# 1.22800392779003
# Vergleich m=100 und m=200
# 1.116945164766721
# Vergleich m=200 und m=500
# 1.0934639349182769
# Vergleich m=500 und m=1000
# 1.0679065893688524
# Vergleich m=1000 und m=10000
# 1.0367238572337378
# Vergleich m=10000 und m=100000
# 1.0133122845465923
#
# p =  1.3
# Vergleich m=5 und m=10
# 32.47398721820397
# Vergleich m=10 und m=50
# 1.8216655721659258
# Vergleich m=50 und m=100
# 1.26955985037225
# Vergleich m=100 und m=200
# 1.1456064931375993
# Vergleich m=200 und m=500
# 1.1102034724378835
# Vergleich m=500 und m=1000
# 1.0810138090957404
# Vergleich m=1000 und m=10000
# 1.0371660774242168
# Vergleich m=10000 und m=100000
# 1.0162327033699508
#
# p =  1.5
# Vergleich m=5 und m=10
# 54.66007244507667
# Vergleich m=10 und m=50
# 2.1471955676801264
# Vergleich m=50 und m=100
# 1.307302845105593
# Vergleich m=100 und m=200
# 1.1684738512604174
# Vergleich m=200 und m=500
# 1.1204225406825512
# Vergleich m=500 und m=1000
# 1.0881457724398043
# Vergleich m=1000 und m=10000
# 1.0372837691030352
# Vergleich m=10000 und m=100000
# 1.017735364040683
#
# p =  1.7
# Vergleich m=5 und m=10
# 91.83628050014079
# Vergleich m=10 und m=50
# 2.5720448854006723
# Vergleich m=50 und m=100
# 1.373373564934847
# Vergleich m=100 und m=200
# 1.1915016925088193
# Vergleich m=200 und m=500
# 1.1300006683272004
# Vergleich m=500 und m=1000
# 1.094207624517921
# Vergleich m=1000 und m=10000
# 1.0369977399935397
# Vergleich m=10000 und m=100000
# 1.0189195722136308
#
# p =  2.0
# Vergleich m=5 und m=10
# 199.9982413458234
# Vergleich m=10 und m=50
# 3.455270592276472
# Vergleich m=50 und m=100
# 1.479838630927733
# Vergleich m=100 und m=200
# 1.2339469063038178
# Vergleich m=200 und m=500
# 1.156244813486561
# Vergleich m=500 und m=1000
# 1.101554568999919
# Vergleich m=1000 und m=10000
# 1.0413732768503838
# Vergleich m=10000 und m=100000
# 1.0204231474358003

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Webspam Datensatz
# %store -r Webspam
print("Webspam Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Webspam_5 = compute_random_evaluations_probabilities_v2(Webspam.X, m=5, p=i, rng=rng)
    data_Webspam_10 = compute_random_evaluations_probabilities_v2(Webspam.X, m=10, p=i, rng=rng)
    data_Webspam_50 = compute_random_evaluations_probabilities_v2(Webspam.X, m=50, p=i, rng=rng)
    data_Webspam_100 = compute_random_evaluations_probabilities_v2(Webspam.X, m=100, p=i, rng=rng)
    data_Webspam_200 = compute_random_evaluations_probabilities_v2(Webspam.X, m=200, p=i, rng=rng)
    data_Webspam_500 = compute_random_evaluations_probabilities_v2(Webspam.X, m=500, p=i, rng=rng)
    data_Webspam_1000 = compute_random_evaluations_probabilities_v2(Webspam.X, m=1000, p=i, rng=rng)
    data_Webspam_10000 = compute_random_evaluations_probabilities_v2(Webspam.X, m=10000, p=i, rng=rng)
    
    data_Webspam_Vergleich_5_10 = np.maximum(data_Webspam_5/data_Webspam_10, data_Webspam_10/data_Webspam_5)
    data_Webspam_Vergleich_10_50 = np.maximum(data_Webspam_10/data_Webspam_50, data_Webspam_50/data_Webspam_10)
    data_Webspam_Vergleich_50_100 = np.maximum(data_Webspam_50/data_Webspam_100, data_Webspam_100/data_Webspam_50)
    data_Webspam_Vergleich_100_200 = np.maximum(data_Webspam_100/data_Webspam_200, data_Webspam_200/data_Webspam_100)
    data_Webspam_Vergleich_200_500 = np.maximum(data_Webspam_200/data_Webspam_500, data_Webspam_500/data_Webspam_200)
    data_Webspam_Vergleich_500_1000 = np.maximum(data_Webspam_500/data_Webspam_1000, data_Webspam_1000/data_Webspam_500)
    data_Webspam_Vergleich_1000_10000 = np.maximum(data_Webspam_1000/data_Webspam_10000, data_Webspam_10000/data_Webspam_1000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Webspam_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Webspam_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Webspam_Vergleich_50_100))
    print("Vergleich m=100 und m=200")
    print(max(data_Webspam_Vergleich_100_200))
    print("Vergleich m=200 und m=500")
    print(max(data_Webspam_Vergleich_200_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Webspam_Vergleich_500_1000))
    print("Vergleich m=1000 und m=10000")
    print(max(data_Webspam_Vergleich_1000_10000))
    print("")
# Out:
# Webspam Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 20.15577063949164
# Vergleich m=10 und m=50
# 10.113448764742385
# Vergleich m=50 und m=100
# 2.0066288032031383
# Vergleich m=100 und m=200
# 1.611587794680479
# Vergleich m=200 und m=500
# 1.3545206462742598
# Vergleich m=500 und m=1000
# 1.2699877580324814
# Vergleich m=1000 und m=10000
# 1.1236175129357417
#
# p =  1.3
# Vergleich m=5 und m=10
# 54.94898296222655
# Vergleich m=10 und m=50
# 19.24209042013935
# Vergleich m=50 und m=100
# 2.4726513170436846
# Vergleich m=100 und m=200
# 1.9031442530985085
# Vergleich m=200 und m=500
# 1.5058673626036874
# Vergleich m=500 und m=1000
# 1.3590288450295096
# Vergleich m=1000 und m=10000
# 1.1610313786882196
#
# p =  1.5
# Vergleich m=5 und m=10
# 112.25199787349814
# Vergleich m=10 und m=50
# 28.89331679215973
# Vergleich m=50 und m=100
# 2.874551524376731
# Vergleich m=100 und m=200
# 2.1336150184324207
# Vergleich m=200 und m=500
# 1.620632660758998
# Vergleich m=500 und m=1000
# 1.4192282105328027
# Vergleich m=1000 und m=10000
# 1.1856926781747488
#
# p =  1.7
# Vergleich m=5 und m=10
# 232.4086237409797
# Vergleich m=10 und m=50
# 42.520299250345936
# Vergleich m=50 und m=100
# 3.336965799910205
# Vergleich m=100 und m=200
# 2.3987629321270156
# Vergleich m=200 und m=500
# 1.744102209737578
# Vergleich m=500 und m=1000
# 1.4803354128173456
# Vergleich m=1000 und m=10000
# 1.2163667409728078
#
# p =  2.0
# Vergleich m=5 und m=10
# 694.3937981005319
# Vergleich m=10 und m=50
# 76.38365793612407
# Vergleich m=50 und m=100
# 4.193038042462047
# Vergleich m=100 und m=200
# 3.0542845243740597
# Vergleich m=200 und m=500
# 1.9293479967716647
# Vergleich m=500 und m=1000
# 1.5704361448319948
# Vergleich m=1000 und m=10000
# 1.2903846328219581

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#KDDCup Datensatz
# %store -r KDDCup
print("KDDCup Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_KDDCup_5 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=5, p=i, rng=rng)
    data_KDDCup_10 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=10, p=i, rng=rng)
    data_KDDCup_50 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=50, p=i, rng=rng)
    data_KDDCup_100 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=100, p=i, rng=rng)
    data_KDDCup_200 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=200, p=i, rng=rng)
    data_KDDCup_500 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=500, p=i, rng=rng)
    data_KDDCup_1000 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=1000, p=i, rng=rng)
    
    data_KDDCup_Vergleich_5_10 = np.maximum(data_KDDCup_5/data_KDDCup_10, data_KDDCup_10/data_KDDCup_5)
    data_KDDCup_Vergleich_10_50 = np.maximum(data_KDDCup_10/data_KDDCup_50, data_KDDCup_50/data_KDDCup_10)
    data_KDDCup_Vergleich_50_100 = np.maximum(data_KDDCup_50/data_KDDCup_100, data_KDDCup_100/data_KDDCup_50)
    data_KDDCup_Vergleich_100_200 = np.maximum(data_KDDCup_100/data_KDDCup_200, data_KDDCup_200/data_KDDCup_100)
    data_KDDCup_Vergleich_200_500 = np.maximum(data_KDDCup_200/data_KDDCup_500, data_KDDCup_500/data_KDDCup_200)
    data_KDDCup_Vergleich_500_1000 = np.maximum(data_KDDCup_500/data_KDDCup_1000, data_KDDCup_1000/data_KDDCup_500)
    
    print("Vergleich m=5 und m=10")
    print(max(data_KDDCup_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_KDDCup_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_KDDCup_Vergleich_50_100))
    print("Vergleich m=100 und m=200")
    print(max(data_KDDCup_Vergleich_100_200))
    print("Vergleich m=200 und m=500")
    print(max(data_KDDCup_Vergleich_200_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_KDDCup_Vergleich_500_1000))
    print("")
# Out:
# KDDCup Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 6.075665202387088
# Vergleich m=10 und m=50
# 3.516661933498137
# Vergleich m=50 und m=100
# 1.6046074446844734
# Vergleich m=100 und m=200
# 1.409951189830791
# Vergleich m=200 und m=500
# 1.3689912004832376
# Vergleich m=500 und m=1000
# 1.183801803010022
#
# p =  1.3
# Vergleich m=5 und m=10
# 9.509912025483732
# Vergleich m=10 und m=50
# 5.399950381475429
# Vergleich m=50 und m=100
# 1.8305118181453748
# Vergleich m=100 und m=200
# 1.5386543193333329
# Vergleich m=200 und m=500
# 1.464835351921972
# Vergleich m=500 und m=1000
# 1.2290356562680143
#
# p =  1.5
# Vergleich m=5 und m=10
# 13.880898110864473
# Vergleich m=10 und m=50
# 7.183900915701974
# Vergleich m=50 und m=100
# 1.9463662522319078
# Vergleich m=100 und m=200
# 1.6081258525463162
# Vergleich m=200 und m=500
# 1.5045095443812269
# Vergleich m=500 und m=1000
# 1.2603998761578266
#
# p =  1.7
# Vergleich m=5 und m=10
# 20.486162651534762
# Vergleich m=10 und m=50
# 9.395284627976583
# Vergleich m=50 und m=100
# 2.0132578054903356
# Vergleich m=100 und m=200
# 1.673770396357959
# Vergleich m=200 und m=500
# 1.5271792755517717
# Vergleich m=500 und m=1000
# 1.287635030849824
#
# p =  2.0
# Vergleich m=5 und m=10
# 38.02763989723094
# Vergleich m=10 und m=50
# 14.560523522355123
# Vergleich m=50 und m=100
# 2.4028129609434266
# Vergleich m=100 und m=200
# 1.7799667311023666
# Vergleich m=200 und m=500
# 1.5852755155549578
# Vergleich m=500 und m=1000
# 1.3418661860929844

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Covertype Datensatz
# %store -r Covertype
print("Covertype Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Covertype_5 = compute_random_evaluations_probabilities_v2(Covertype.X, m=5, p=i, rng=rng)
    data_Covertype_10 = compute_random_evaluations_probabilities_v2(Covertype.X, m=10, p=i, rng=rng)
    data_Covertype_50 = compute_random_evaluations_probabilities_v2(Covertype.X, m=50, p=i, rng=rng)
    data_Covertype_100 = compute_random_evaluations_probabilities_v2(Covertype.X, m=100, p=i, rng=rng)
    data_Covertype_200 = compute_random_evaluations_probabilities_v2(Covertype.X, m=200, p=i, rng=rng)
    data_Covertype_500 = compute_random_evaluations_probabilities_v2(Covertype.X, m=500, p=i, rng=rng)
    data_Covertype_1000 = compute_random_evaluations_probabilities_v2(Covertype.X, m=1000, p=i, rng=rng)
    
    data_Covertype_Vergleich_5_10 = np.maximum(data_Covertype_5/data_Covertype_10, data_Covertype_10/data_Covertype_5)
    data_Covertype_Vergleich_10_50 = np.maximum(data_Covertype_10/data_Covertype_50, data_Covertype_50/data_Covertype_10)
    data_Covertype_Vergleich_50_100 = np.maximum(data_Covertype_50/data_Covertype_100, data_Covertype_100/data_Covertype_50)
    data_Covertype_Vergleich_100_200 = np.maximum(data_Covertype_100/data_Covertype_200, data_Covertype_200/data_Covertype_100)
    data_Covertype_Vergleich_200_500 = np.maximum(data_Covertype_200/data_Covertype_500, data_Covertype_500/data_Covertype_200)
    data_Covertype_Vergleich_500_1000 = np.maximum(data_Covertype_500/data_Covertype_1000, data_Covertype_1000/data_Covertype_500)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Covertype_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Covertype_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Covertype_Vergleich_50_100))
    print("Vergleich m=100 und m=200")
    print(max(data_Covertype_Vergleich_100_200))
    print("Vergleich m=200 und m=500")
    print(max(data_Covertype_Vergleich_200_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Covertype_Vergleich_500_1000))
    print("")
# Out:
# Covertype Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 14.204676612863175
# Vergleich m=10 und m=50
# 4.842968897063879
# Vergleich m=50 und m=100
# 1.5954716142185346
# Vergleich m=100 und m=200
# 1.4435334118648895
# Vergleich m=200 und m=500
# 1.2555327358698274
# Vergleich m=500 und m=1000
# 1.1687317100611794
#
# p =  1.3
# Vergleich m=5 und m=10
# 29.73767912130226
# Vergleich m=10 und m=50
# 7.796540606732713
# Vergleich m=50 und m=100
# 1.8568710499698304
# Vergleich m=100 und m=200
# 1.5800591311103378
# Vergleich m=200 und m=500
# 1.334544105496976
# Vergleich m=500 und m=1000
# 1.2238241164107297
#
# p =  1.5
# Vergleich m=5 und m=10
# 48.4854986625881
# Vergleich m=10 und m=50
# 10.63825125076809
# Vergleich m=50 und m=100
# 2.1242236709056663
# Vergleich m=100 und m=200
# 1.6876939403652396
# Vergleich m=200 und m=500
# 1.3910018413307752
# Vergleich m=500 und m=1000
# 1.262608395749612
#
# p =  1.7
# Vergleich m=5 und m=10
# 79.91768166752821
# Vergleich m=10 und m=50
# 14.695182374170468
# Vergleich m=50 und m=100
# 2.4446628973084152
# Vergleich m=100 und m=200
# 1.8284156382327863
# Vergleich m=200 und m=500
# 1.4511295017395098
# Vergleich m=500 und m=1000
# 1.303106574089605
#
# p =  2.0
# Vergleich m=5 und m=10
# 180.6569959695666
# Vergleich m=10 und m=50
# 25.668023211756573
# Vergleich m=50 und m=100
# 3.0437578735458493
# Vergleich m=100 und m=200
# 2.053394422676671
# Vergleich m=200 und m=500
# 1.5820039607636533
# Vergleich m=500 und m=1000
# 1.3698854737258817
