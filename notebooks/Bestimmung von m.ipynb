# %%
#Iris Datensatz mit p = 1.0

# load all datasets
# %store -r Iris
print("Iris Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 1.0
p = 1.0
print("p = 1.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Iris_v1_1 = compute_random_evaluations_probabilities(Iris.X, m=1, p=p, rng=rng)
data_Iris_v1_2 = compute_random_evaluations_probabilities(Iris.X, m=2, p=p, rng=rng)
data_Iris_v1_3 = compute_random_evaluations_probabilities(Iris.X, m=3, p=p, rng=rng)
data_Iris_v1_4 = compute_random_evaluations_probabilities(Iris.X, m=4, p=p, rng=rng)
data_Iris_v1_5 = compute_random_evaluations_probabilities(Iris.X, m=5, p=p, rng=rng)
data_Iris_v1_10 = compute_random_evaluations_probabilities(Iris.X, m=10, p=p, rng=rng)
data_Iris_v1_20 = compute_random_evaluations_probabilities(Iris.X, m=20, p=p, rng=rng)
data_Iris_v1_50 = compute_random_evaluations_probabilities(Iris.X, m=50, p=p, rng=rng)
data_Iris_v1_100 = compute_random_evaluations_probabilities(Iris.X, m=100, p=p, rng=rng)
data_Iris_v1_200 = compute_random_evaluations_probabilities(Iris.X, m=200, p=p, rng=rng)
data_Iris_v1_1000 = compute_random_evaluations_probabilities(Iris.X, m=1000, p=p, rng=rng)
data_Iris_v1_10000 = compute_random_evaluations_probabilities(Iris.X, m=10000, p=p, rng=rng)
data_Iris_v1_100000 = compute_random_evaluations_probabilities(Iris.X, m=100000, p=p, rng=rng)
print("m=1",data_Iris_v1_1[range(5)],",", data_Iris_v1_1[-5:])
print("m=2",data_Iris_v1_2[range(5)],",", data_Iris_v1_2[-5:])
print("m=3",data_Iris_v1_3[range(5)],",", data_Iris_v1_3[-5:])
print("m=4",data_Iris_v1_4[range(5)],",", data_Iris_v1_4[-5:])
print("m=5",data_Iris_v1_5[range(5)],",", data_Iris_v1_5[-5:])
print("m=10",data_Iris_v1_10[range(5)],",", data_Iris_v1_10[-5:])
print("m=20",data_Iris_v1_20[range(5)],",", data_Iris_v1_20[-5:])
print("m=50",data_Iris_v1_50[range(5)],",", data_Iris_v1_50[-5:])
print("m=100",data_Iris_v1_100[range(5)],",", data_Iris_v1_100[-5:])
print("m=200",data_Iris_v1_200[range(5)],",", data_Iris_v1_200[-5:])
print("m=1000",data_Iris_v1_1000[range(5)],",", data_Iris_v1_1000[-5:])
print("m=10000",data_Iris_v1_10000[range(5)],",", data_Iris_v1_10000[-5:])
print("m=100000",data_Iris_v1_100000[range(5)],",", data_Iris_v1_100000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Iris_v2_1 = compute_random_evaluations_probabilities_v2(Iris.X, m=1, p=p, rng=rng)
data_Iris_v2_2 = compute_random_evaluations_probabilities_v2(Iris.X, m=2, p=p, rng=rng)
data_Iris_v2_3 = compute_random_evaluations_probabilities_v2(Iris.X, m=3, p=p, rng=rng)
data_Iris_v2_4 = compute_random_evaluations_probabilities_v2(Iris.X, m=4, p=p, rng=rng)
data_Iris_v2_5 = compute_random_evaluations_probabilities_v2(Iris.X, m=5, p=p, rng=rng)
data_Iris_v2_10 = compute_random_evaluations_probabilities_v2(Iris.X, m=10, p=p, rng=rng)
data_Iris_v2_20 = compute_random_evaluations_probabilities_v2(Iris.X, m=20, p=p, rng=rng)
data_Iris_v2_50 = compute_random_evaluations_probabilities_v2(Iris.X, m=50, p=p, rng=rng)
data_Iris_v2_100 = compute_random_evaluations_probabilities_v2(Iris.X, m=100, p=p, rng=rng)
data_Iris_v2_200 = compute_random_evaluations_probabilities_v2(Iris.X, m=200, p=p, rng=rng)
data_Iris_v2_1000 = compute_random_evaluations_probabilities_v2(Iris.X, m=1000, p=p, rng=rng)
data_Iris_v2_10000 = compute_random_evaluations_probabilities_v2(Iris.X, m=10000, p=p, rng=rng)
data_Iris_v2_100000 = compute_random_evaluations_probabilities_v2(Iris.X, m=100000, p=p, rng=rng)
print("m=1",data_Iris_v2_1[range(5)],",", data_Iris_v2_1[-5:])
print("m=2",data_Iris_v2_2[range(5)],",", data_Iris_v2_2[-5:])
print("m=3",data_Iris_v2_3[range(5)],",", data_Iris_v2_3[-5:])
print("m=4",data_Iris_v2_4[range(5)],",", data_Iris_v2_4[-5:])
print("m=5",data_Iris_v2_5[range(5)],",", data_Iris_v2_5[-5:])
print("m=10",data_Iris_v2_10[range(5)],",", data_Iris_v2_10[-5:])
print("m=20",data_Iris_v2_20[range(5)],",", data_Iris_v2_20[-5:])
print("m=50",data_Iris_v2_50[range(5)],",", data_Iris_v2_50[-5:])
print("m=100",data_Iris_v2_100[range(5)],",", data_Iris_v2_100[-5:])
print("m=200",data_Iris_v2_200[range(5)],",", data_Iris_v2_200[-5:])
print("m=1000",data_Iris_v2_1000[range(5)],",", data_Iris_v2_1000[-5:])
print("m=10000",data_Iris_v2_10000[range(5)],",", data_Iris_v2_10000[-5:])
print("m=100000",data_Iris_v2_100000[range(5)],",", data_Iris_v2_100000[-5:])
# Out:
# Iris Datensatz
# p = 1.0
# Version 1
# m=1 [0.01202921 0.01158689 0.01373209 0.01281893 0.01282035] , [0.00131246 0.00083847 0.00056242 0.00385309 0.00109283]
# m=2 [0.00695882 0.00300434 0.00084998 0.00212012 0.00854686] , [0.00173755 0.009375   0.00136586 0.00754905 0.0014774 ]
# m=3 [0.00767572 0.00903164 0.01010837 0.01053794 0.0081715 ] , [0.00711909 0.00391553 0.00558719 0.00494237 0.00278708]
# m=4 [0.00550716 0.00770387 0.00847055 0.00921619 0.00588005] , [0.00611137 0.00630728 0.00521134 0.00243399 0.00428941]
# m=5 [0.00564814 0.00656269 0.00694067 0.00789012 0.00617508] , [0.00815547 0.00577187 0.00629444 0.00502239 0.00291993]
# m=10 [0.00704719 0.00786818 0.00809566 0.00820165 0.00711598] , [0.00672852 0.00643587 0.0060972  0.00531495 0.00459175]
# m=20 [0.00768645 0.00723592 0.00782557 0.00749655 0.00805783] , [0.00505698 0.00698588 0.00459887 0.00549251 0.00382647]
# ...

# %%
#Iris Datensatz mit p = 2.0

# load all datasets
# %store -r Iris
print("Iris Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 2.0
p = 2.0
print("p = 2.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Iris_v1_1 = compute_random_evaluations_probabilities(Iris.X, m=1, p=p, rng=rng)
data_Iris_v1_2 = compute_random_evaluations_probabilities(Iris.X, m=2, p=p, rng=rng)
data_Iris_v1_3 = compute_random_evaluations_probabilities(Iris.X, m=3, p=p, rng=rng)
data_Iris_v1_4 = compute_random_evaluations_probabilities(Iris.X, m=4, p=p, rng=rng)
data_Iris_v1_5 = compute_random_evaluations_probabilities(Iris.X, m=5, p=p, rng=rng)
data_Iris_v1_10 = compute_random_evaluations_probabilities(Iris.X, m=10, p=p, rng=rng)
data_Iris_v1_20 = compute_random_evaluations_probabilities(Iris.X, m=20, p=p, rng=rng)
data_Iris_v1_50 = compute_random_evaluations_probabilities(Iris.X, m=50, p=p, rng=rng)
data_Iris_v1_100 = compute_random_evaluations_probabilities(Iris.X, m=100, p=p, rng=rng)
data_Iris_v1_200 = compute_random_evaluations_probabilities(Iris.X, m=200, p=p, rng=rng)
data_Iris_v1_1000 = compute_random_evaluations_probabilities(Iris.X, m=1000, p=p, rng=rng)
data_Iris_v1_10000 = compute_random_evaluations_probabilities(Iris.X, m=10000, p=p, rng=rng)
data_Iris_v1_100000 = compute_random_evaluations_probabilities(Iris.X, m=100000, p=p, rng=rng)
print("m=1",data_Iris_v1_1[range(5)],",", data_Iris_v1_1[-5:])
print("m=2",data_Iris_v1_2[range(5)],",", data_Iris_v1_2[-5:])
print("m=3",data_Iris_v1_3[range(5)],",", data_Iris_v1_3[-5:])
print("m=4",data_Iris_v1_4[range(5)],",", data_Iris_v1_4[-5:])
print("m=5",data_Iris_v1_5[range(5)],",", data_Iris_v1_5[-5:])
print("m=10",data_Iris_v1_10[range(5)],",", data_Iris_v1_10[-5:])
print("m=20",data_Iris_v1_20[range(5)],",", data_Iris_v1_20[-5:])
print("m=50",data_Iris_v1_50[range(5)],",", data_Iris_v1_50[-5:])
print("m=100",data_Iris_v1_100[range(5)],",", data_Iris_v1_100[-5:])
print("m=200",data_Iris_v1_200[range(5)],",", data_Iris_v1_200[-5:])
print("m=1000",data_Iris_v1_1000[range(5)],",", data_Iris_v1_1000[-5:])
print("m=10000",data_Iris_v1_10000[range(5)],",", data_Iris_v1_10000[-5:])
print("m=100000",data_Iris_v1_100000[range(5)],",", data_Iris_v1_100000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Iris_v2_1 = compute_random_evaluations_probabilities_v2(Iris.X, m=1, p=p, rng=rng)
data_Iris_v2_2 = compute_random_evaluations_probabilities_v2(Iris.X, m=2, p=p, rng=rng)
data_Iris_v2_3 = compute_random_evaluations_probabilities_v2(Iris.X, m=3, p=p, rng=rng)
data_Iris_v2_4 = compute_random_evaluations_probabilities_v2(Iris.X, m=4, p=p, rng=rng)
data_Iris_v2_5 = compute_random_evaluations_probabilities_v2(Iris.X, m=5, p=p, rng=rng)
data_Iris_v2_10 = compute_random_evaluations_probabilities_v2(Iris.X, m=10, p=p, rng=rng)
data_Iris_v2_20 = compute_random_evaluations_probabilities_v2(Iris.X, m=20, p=p, rng=rng)
data_Iris_v2_50 = compute_random_evaluations_probabilities_v2(Iris.X, m=50, p=p, rng=rng)
data_Iris_v2_100 = compute_random_evaluations_probabilities_v2(Iris.X, m=100, p=p, rng=rng)
data_Iris_v2_200 = compute_random_evaluations_probabilities_v2(Iris.X, m=200, p=p, rng=rng)
data_Iris_v2_1000 = compute_random_evaluations_probabilities_v2(Iris.X, m=1000, p=p, rng=rng)
data_Iris_v2_10000 = compute_random_evaluations_probabilities_v2(Iris.X, m=10000, p=p, rng=rng)
data_Iris_v2_100000 = compute_random_evaluations_probabilities_v2(Iris.X, m=100000, p=p, rng=rng)
print("m=1",data_Iris_v2_1[range(5)],",", data_Iris_v2_1[-5:])
print("m=2",data_Iris_v2_2[range(5)],",", data_Iris_v2_2[-5:])
print("m=3",data_Iris_v2_3[range(5)],",", data_Iris_v2_3[-5:])
print("m=4",data_Iris_v2_4[range(5)],",", data_Iris_v2_4[-5:])
print("m=5",data_Iris_v2_5[range(5)],",", data_Iris_v2_5[-5:])
print("m=10",data_Iris_v2_10[range(5)],",", data_Iris_v2_10[-5:])
print("m=20",data_Iris_v2_20[range(5)],",", data_Iris_v2_20[-5:])
print("m=50",data_Iris_v2_50[range(5)],",", data_Iris_v2_50[-5:])
print("m=100",data_Iris_v2_100[range(5)],",", data_Iris_v2_100[-5:])
print("m=200",data_Iris_v2_200[range(5)],",", data_Iris_v2_200[-5:])
print("m=1000",data_Iris_v2_1000[range(5)],",", data_Iris_v2_1000[-5:])
print("m=10000",data_Iris_v2_10000[range(5)],",", data_Iris_v2_10000[-5:])
print("m=100000",data_Iris_v2_100000[range(5)],",", data_Iris_v2_100000[-5:])
# Out:
# Iris Datensatz
# p = 2.0
# Version 1
# m=1 [0.01390889 0.01290482 0.01812555 0.01579508 0.01579858] , [1.65572801e-04 6.75765569e-05 3.04047826e-05 1.42704043e-03
#  1.14794912e-04]
# m=2 [4.52211166e-03 9.49914726e-04 7.34191762e-05 4.61676176e-04
#  6.73712708e-03] , [0.00047367 0.00824021 0.00019536 0.00523276 0.00025593]
# m=3 [0.00668228 0.00929599 0.01076228 0.01197482 0.0078936 ] , [0.00555706 0.00375467 0.00337745 0.00563536 0.00099093]
# m=4 [0.00473659 0.00765337 0.00865115 0.01009764 0.00522304] , [0.00503971 0.00677075 0.00361716 0.00079441 0.00223914]
# m=5 [0.00526778 0.00612749 0.00719181 0.00825947 0.00576289] , [0.00780703 0.00445346 0.00496294 0.00477128 0.00155756]
# m=10 [0.00746177 0.00902041 0.00933951 0.00939803 0.00750617] , [0.00631421 0.00560742 0.00501073 0.00413677 0.00303172]
# m=20 [0.00746975 0.00761428 0.00782927 0.00765698 0.00822258] , [0.0041773  0.00660643 0.00331973 0.00447434 0.00233728]
# ...

# %%
#Example2D Datensatz mit p = 1.0

# load all datasets
# %store -r Example2D
print("Example2D Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 1.0
p = 1.0
print("p = 1.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Example2D_v1_1 = compute_random_evaluations_probabilities(Example2D.X, m=1, p=p, rng=rng)
data_Example2D_v1_2 = compute_random_evaluations_probabilities(Example2D.X, m=2, p=p, rng=rng)
data_Example2D_v1_3 = compute_random_evaluations_probabilities(Example2D.X, m=3, p=p, rng=rng)
data_Example2D_v1_4 = compute_random_evaluations_probabilities(Example2D.X, m=4, p=p, rng=rng)
data_Example2D_v1_5 = compute_random_evaluations_probabilities(Example2D.X, m=5, p=p, rng=rng)
data_Example2D_v1_10 = compute_random_evaluations_probabilities(Example2D.X, m=10, p=p, rng=rng)
data_Example2D_v1_20 = compute_random_evaluations_probabilities(Example2D.X, m=20, p=p, rng=rng)
data_Example2D_v1_50 = compute_random_evaluations_probabilities(Example2D.X, m=50, p=p, rng=rng)
data_Example2D_v1_100 = compute_random_evaluations_probabilities(Example2D.X, m=100, p=p, rng=rng)
data_Example2D_v1_200 = compute_random_evaluations_probabilities(Example2D.X, m=200, p=p, rng=rng)
data_Example2D_v1_1000 = compute_random_evaluations_probabilities(Example2D.X, m=1000, p=p, rng=rng)
data_Example2D_v1_10000 = compute_random_evaluations_probabilities(Example2D.X, m=10000, p=p, rng=rng)
data_Example2D_v1_100000 = compute_random_evaluations_probabilities(Example2D.X, m=100000, p=p, rng=rng)
print("m=1",data_Example2D_v1_1[range(5)],",", data_Example2D_v1_1[-5:])
print("m=2",data_Example2D_v1_2[range(5)],",", data_Example2D_v1_2[-5:])
print("m=3",data_Example2D_v1_3[range(5)],",", data_Example2D_v1_3[-5:])
print("m=4",data_Example2D_v1_4[range(5)],",", data_Example2D_v1_4[-5:])
print("m=5",data_Example2D_v1_5[range(5)],",", data_Example2D_v1_5[-5:])
print("m=10",data_Example2D_v1_10[range(5)],",", data_Example2D_v1_10[-5:])
print("m=20",data_Example2D_v1_20[range(5)],",", data_Example2D_v1_20[-5:])
print("m=50",data_Example2D_v1_50[range(5)],",", data_Example2D_v1_50[-5:])
print("m=100",data_Example2D_v1_100[range(5)],",", data_Example2D_v1_100[-5:])
print("m=200",data_Example2D_v1_200[range(5)],",", data_Example2D_v1_200[-5:])
print("m=1000",data_Example2D_v1_1000[range(5)],",", data_Example2D_v1_1000[-5:])
print("m=10000",data_Example2D_v1_10000[range(5)],",", data_Example2D_v1_10000[-5:])
print("m=100000",data_Example2D_v1_100000[range(5)],",", data_Example2D_v1_100000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Example2D_v2_1 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1, p=p, rng=rng)
data_Example2D_v2_2 = compute_random_evaluations_probabilities_v2(Example2D.X, m=2, p=p, rng=rng)
data_Example2D_v2_3 = compute_random_evaluations_probabilities_v2(Example2D.X, m=3, p=p, rng=rng)
data_Example2D_v2_4 = compute_random_evaluations_probabilities_v2(Example2D.X, m=4, p=p, rng=rng)
data_Example2D_v2_5 = compute_random_evaluations_probabilities_v2(Example2D.X, m=5, p=p, rng=rng)
data_Example2D_v2_10 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10, p=p, rng=rng)
data_Example2D_v2_20 = compute_random_evaluations_probabilities_v2(Example2D.X, m=20, p=p, rng=rng)
data_Example2D_v2_50 = compute_random_evaluations_probabilities_v2(Example2D.X, m=50, p=p, rng=rng)
data_Example2D_v2_100 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100, p=p, rng=rng)
data_Example2D_v2_200 = compute_random_evaluations_probabilities_v2(Example2D.X, m=200, p=p, rng=rng)
data_Example2D_v2_1000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1000, p=p, rng=rng)
data_Example2D_v2_10000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10000, p=p, rng=rng)
data_Example2D_v2_100000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100000, p=p, rng=rng)
print("m=1",data_Example2D_v2_1[range(5)],",", data_Example2D_v2_1[-5:])
print("m=2",data_Example2D_v2_2[range(5)],",", data_Example2D_v2_2[-5:])
print("m=3",data_Example2D_v2_3[range(5)],",", data_Example2D_v2_3[-5:])
print("m=4",data_Example2D_v2_4[range(5)],",", data_Example2D_v2_4[-5:])
print("m=5",data_Example2D_v2_5[range(5)],",", data_Example2D_v2_5[-5:])
print("m=10",data_Example2D_v2_10[range(5)],",", data_Example2D_v2_10[-5:])
print("m=20",data_Example2D_v2_20[range(5)],",", data_Example2D_v2_20[-5:])
print("m=50",data_Example2D_v2_50[range(5)],",", data_Example2D_v2_50[-5:])
print("m=100",data_Example2D_v2_100[range(5)],",", data_Example2D_v2_100[-5:])
print("m=200",data_Example2D_v2_200[range(5)],",", data_Example2D_v2_200[-5:])
print("m=1000",data_Example2D_v2_1000[range(5)],",", data_Example2D_v2_1000[-5:])
print("m=10000",data_Example2D_v2_10000[range(5)],",", data_Example2D_v2_10000[-5:])
print("m=100000",data_Example2D_v2_100000[range(5)],",", data_Example2D_v2_100000[-5:])
# Out:
# Example2D Datensatz
# p = 1.0
# Version 1
# m=1 [0.00367724 0.00502491 0.00325977 0.00761159 0.00211175] , [0.00539877 0.00306737 0.01160052 0.01006035 0.0084695 ]
# m=2 [0.00792439 0.0025348  0.00492274 0.00170326 0.00561439] , [0.00018278 0.00887206 0.0180317  0.01859776 0.00525068]
# m=3 [0.00582293 0.00125393 0.00550891 0.00439147 0.00360442] , [0.00162664 0.00658103 0.01600721 0.01669129 0.00559888]
# m=4 [0.00372491 0.00189814 0.00588829 0.00448442 0.0052502 ] , [0.00208562 0.00402328 0.01293077 0.01174458 0.00629174]
# m=5 [0.00518165 0.00245575 0.00222189 0.00586451 0.00643935] , [0.00236854 0.00624939 0.01378963 0.01118573 0.00756994]
# m=10 [0.00419156 0.00284524 0.00473685 0.005717   0.00365059] , [0.00328123 0.0048629  0.01548044 0.01437631 0.00751615]
# m=20 [0.00574869 0.00304759 0.00523896 0.00448317 0.00431418] , [0.00305899 0.00619346 0.01331506 0.01344546 0.00582696]
# ...

# %%
#Example2D Datensatz mit p = 2.0

# load all datasets
# %store -r Example2D
print("Example2D Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 2.0
p = 2.0
print("p = 2.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Example2D_v1_1 = compute_random_evaluations_probabilities(Example2D.X, m=1, p=p, rng=rng)
data_Example2D_v1_2 = compute_random_evaluations_probabilities(Example2D.X, m=2, p=p, rng=rng)
data_Example2D_v1_3 = compute_random_evaluations_probabilities(Example2D.X, m=3, p=p, rng=rng)
data_Example2D_v1_4 = compute_random_evaluations_probabilities(Example2D.X, m=4, p=p, rng=rng)
data_Example2D_v1_5 = compute_random_evaluations_probabilities(Example2D.X, m=5, p=p, rng=rng)
data_Example2D_v1_10 = compute_random_evaluations_probabilities(Example2D.X, m=10, p=p, rng=rng)
data_Example2D_v1_20 = compute_random_evaluations_probabilities(Example2D.X, m=20, p=p, rng=rng)
data_Example2D_v1_50 = compute_random_evaluations_probabilities(Example2D.X, m=50, p=p, rng=rng)
data_Example2D_v1_100 = compute_random_evaluations_probabilities(Example2D.X, m=100, p=p, rng=rng)
data_Example2D_v1_200 = compute_random_evaluations_probabilities(Example2D.X, m=200, p=p, rng=rng)
data_Example2D_v1_1000 = compute_random_evaluations_probabilities(Example2D.X, m=1000, p=p, rng=rng)
data_Example2D_v1_10000 = compute_random_evaluations_probabilities(Example2D.X, m=10000, p=p, rng=rng)
data_Example2D_v1_100000 = compute_random_evaluations_probabilities(Example2D.X, m=100000, p=p, rng=rng)
print("m=1",data_Example2D_v1_1[range(5)],",", data_Example2D_v1_1[-5:])
print("m=2",data_Example2D_v1_2[range(5)],",", data_Example2D_v1_2[-5:])
print("m=3",data_Example2D_v1_3[range(5)],",", data_Example2D_v1_3[-5:])
print("m=4",data_Example2D_v1_4[range(5)],",", data_Example2D_v1_4[-5:])
print("m=5",data_Example2D_v1_5[range(5)],",", data_Example2D_v1_5[-5:])
print("m=10",data_Example2D_v1_10[range(5)],",", data_Example2D_v1_10[-5:])
print("m=20",data_Example2D_v1_20[range(5)],",", data_Example2D_v1_20[-5:])
print("m=50",data_Example2D_v1_50[range(5)],",", data_Example2D_v1_50[-5:])
print("m=100",data_Example2D_v1_100[range(5)],",", data_Example2D_v1_100[-5:])
print("m=200",data_Example2D_v1_200[range(5)],",", data_Example2D_v1_200[-5:])
print("m=1000",data_Example2D_v1_1000[range(5)],",", data_Example2D_v1_1000[-5:])
print("m=10000",data_Example2D_v1_10000[range(5)],",", data_Example2D_v1_10000[-5:])
print("m=100000",data_Example2D_v1_100000[range(5)],",", data_Example2D_v1_100000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Example2D_v2_1 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1, p=p, rng=rng)
data_Example2D_v2_2 = compute_random_evaluations_probabilities_v2(Example2D.X, m=2, p=p, rng=rng)
data_Example2D_v2_3 = compute_random_evaluations_probabilities_v2(Example2D.X, m=3, p=p, rng=rng)
data_Example2D_v2_4 = compute_random_evaluations_probabilities_v2(Example2D.X, m=4, p=p, rng=rng)
data_Example2D_v2_5 = compute_random_evaluations_probabilities_v2(Example2D.X, m=5, p=p, rng=rng)
data_Example2D_v2_10 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10, p=p, rng=rng)
data_Example2D_v2_20 = compute_random_evaluations_probabilities_v2(Example2D.X, m=20, p=p, rng=rng)
data_Example2D_v2_50 = compute_random_evaluations_probabilities_v2(Example2D.X, m=50, p=p, rng=rng)
data_Example2D_v2_100 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100, p=p, rng=rng)
data_Example2D_v2_200 = compute_random_evaluations_probabilities_v2(Example2D.X, m=200, p=p, rng=rng)
data_Example2D_v2_1000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1000, p=p, rng=rng)
data_Example2D_v2_10000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10000, p=p, rng=rng)
data_Example2D_v2_100000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100000, p=p, rng=rng)
print("m=1",data_Example2D_v2_1[range(5)],",", data_Example2D_v2_1[-5:])
print("m=2",data_Example2D_v2_2[range(5)],",", data_Example2D_v2_2[-5:])
print("m=3",data_Example2D_v2_3[range(5)],",", data_Example2D_v2_3[-5:])
print("m=4",data_Example2D_v2_4[range(5)],",", data_Example2D_v2_4[-5:])
print("m=5",data_Example2D_v2_5[range(5)],",", data_Example2D_v2_5[-5:])
print("m=10",data_Example2D_v2_10[range(5)],",", data_Example2D_v2_10[-5:])
print("m=20",data_Example2D_v2_20[range(5)],",", data_Example2D_v2_20[-5:])
print("m=50",data_Example2D_v2_50[range(5)],",", data_Example2D_v2_50[-5:])
print("m=100",data_Example2D_v2_100[range(5)],",", data_Example2D_v2_100[-5:])
print("m=200",data_Example2D_v2_200[range(5)],",", data_Example2D_v2_200[-5:])
print("m=1000",data_Example2D_v2_1000[range(5)],",", data_Example2D_v2_1000[-5:])
print("m=10000",data_Example2D_v2_10000[range(5)],",", data_Example2D_v2_10000[-5:])
print("m=100000",data_Example2D_v2_100000[range(5)],",", data_Example2D_v2_100000[-5:])
# Out:
# Example2D Datensatz
# p = 2.0
# Version 1
# m=1 [0.00188412 0.00351819 0.0014806  0.00807262 0.00062137] , [0.00406119 0.00131098 0.01875076 0.0141023  0.00999492]
# m=2 [0.00637511 0.00065262 0.00249939 0.00030034 0.00322228] , [4.08528591e-06 7.99314727e-03 3.30162366e-02 3.51061114e-02
#  2.80574540e-03]
# m=3 [0.00360829 0.00042781 0.00443586 0.00203432 0.00162869] , [0.0002714  0.00442544 0.02767861 0.02846782 0.00431278]
# m=4 [0.0019472  0.00049882 0.00629252 0.00296662 0.00327104] , [0.00058305 0.00261415 0.02092927 0.018193   0.00494552]
# m=5 [0.00404258 0.00145943 0.00060152 0.00431848 0.00484723] , [0.00101137 0.0051513  0.02433459 0.01665572 0.00654878]
# m=10 [0.00297113 0.00141083 0.0029783  0.0038278  0.0024612 ] , [0.00158492 0.00364825 0.0271     0.02453349 0.00648496]
# m=20 [0.00484238 0.00180802 0.00402977 0.00284395 0.00300855] , [0.00144994 0.00557679 0.02190763 0.02214238 0.00436228]
# ...

# %%
#Webspam Datensatz mit p = 1.0

# load all datasets
# %store -r Webspam
print("Webspam Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 1.0
p = 1.0
print("p = 1.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Webspam_v1_1 = compute_random_evaluations_probabilities(Webspam.X, m=1, p=p, rng=rng)
data_Webspam_v1_2 = compute_random_evaluations_probabilities(Webspam.X, m=2, p=p, rng=rng)
data_Webspam_v1_3 = compute_random_evaluations_probabilities(Webspam.X, m=3, p=p, rng=rng)
data_Webspam_v1_4 = compute_random_evaluations_probabilities(Webspam.X, m=4, p=p, rng=rng)
data_Webspam_v1_5 = compute_random_evaluations_probabilities(Webspam.X, m=5, p=p, rng=rng)
data_Webspam_v1_10 = compute_random_evaluations_probabilities(Webspam.X, m=10, p=p, rng=rng)
data_Webspam_v1_20 = compute_random_evaluations_probabilities(Webspam.X, m=20, p=p, rng=rng)
data_Webspam_v1_50 = compute_random_evaluations_probabilities(Webspam.X, m=50, p=p, rng=rng)
data_Webspam_v1_100 = compute_random_evaluations_probabilities(Webspam.X, m=100, p=p, rng=rng)
data_Webspam_v1_200 = compute_random_evaluations_probabilities(Webspam.X, m=200, p=p, rng=rng)
data_Webspam_v1_1000 = compute_random_evaluations_probabilities(Webspam.X, m=1000, p=p, rng=rng)
print("m=1",data_Webspam_v1_1[range(5)],",", data_Webspam_v1_1[-5:])
print("m=2",data_Webspam_v1_2[range(5)],",", data_Webspam_v1_2[-5:])
print("m=3",data_Webspam_v1_3[range(5)],",", data_Webspam_v1_3[-5:])
print("m=4",data_Webspam_v1_4[range(5)],",", data_Webspam_v1_4[-5:])
print("m=5",data_Webspam_v1_5[range(5)],",", data_Webspam_v1_5[-5:])
print("m=10",data_Webspam_v1_10[range(5)],",", data_Webspam_v1_10[-5:])
print("m=20",data_Webspam_v1_20[range(5)],",", data_Webspam_v1_20[-5:])
print("m=50",data_Webspam_v1_50[range(5)],",", data_Webspam_v1_50[-5:])
print("m=100",data_Webspam_v1_100[range(5)],",", data_Webspam_v1_100[-5:])
print("m=200",data_Webspam_v1_200[range(5)],",", data_Webspam_v1_200[-5:])
print("m=1000",data_Webspam_v1_1000[range(5)],",", data_Webspam_v1_1000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Webspam_v2_1 = compute_random_evaluations_probabilities_v2(Webspam.X, m=1, p=p, rng=rng)
data_Webspam_v2_2 = compute_random_evaluations_probabilities_v2(Webspam.X, m=2, p=p, rng=rng)
data_Webspam_v2_3 = compute_random_evaluations_probabilities_v2(Webspam.X, m=3, p=p, rng=rng)
data_Webspam_v2_4 = compute_random_evaluations_probabilities_v2(Webspam.X, m=4, p=p, rng=rng)
data_Webspam_v2_5 = compute_random_evaluations_probabilities_v2(Webspam.X, m=5, p=p, rng=rng)
data_Webspam_v2_10 = compute_random_evaluations_probabilities_v2(Webspam.X, m=10, p=p, rng=rng)
data_Webspam_v2_20 = compute_random_evaluations_probabilities_v2(Webspam.X, m=20, p=p, rng=rng)
data_Webspam_v2_50 = compute_random_evaluations_probabilities_v2(Webspam.X, m=50, p=p, rng=rng)
data_Webspam_v2_100 = compute_random_evaluations_probabilities_v2(Webspam.X, m=100, p=p, rng=rng)
data_Webspam_v2_200 = compute_random_evaluations_probabilities_v2(Webspam.X, m=200, p=p, rng=rng)
data_Webspam_v2_1000 = compute_random_evaluations_probabilities_v2(Webspam.X, m=1000, p=p, rng=rng)
print("m=1",data_Webspam_v2_1[range(5)],",", data_Webspam_v2_1[-5:])
print("m=2",data_Webspam_v2_2[range(5)],",", data_Webspam_v2_2[-5:])
print("m=3",data_Webspam_v2_3[range(5)],",", data_Webspam_v2_3[-5:])
print("m=4",data_Webspam_v2_4[range(5)],",", data_Webspam_v2_4[-5:])
print("m=5",data_Webspam_v2_5[range(5)],",", data_Webspam_v2_5[-5:])
print("m=10",data_Webspam_v2_10[range(5)],",", data_Webspam_v2_10[-5:])
print("m=20",data_Webspam_v2_20[range(5)],",", data_Webspam_v2_20[-5:])
print("m=50",data_Webspam_v2_50[range(5)],",", data_Webspam_v2_50[-5:])
print("m=100",data_Webspam_v2_100[range(5)],",", data_Webspam_v2_100[-5:])
print("m=200",data_Webspam_v2_200[range(5)],",", data_Webspam_v2_200[-5:])
print("m=1000",data_Webspam_v2_1000[range(5)],",", data_Webspam_v2_1000[-5:])
# Out:
# Webspam Datensatz
# p = 1.0
# Version 1
# m=1 [2.41812068e-08 3.45279901e-06 2.83606756e-06 1.16948504e-06
#  5.62743507e-06] , [4.43469550e-07 2.42916172e-08 6.91644300e-06 1.05189522e-06
#  4.14178293e-07]
# m=2 [2.67447307e-06 1.66856136e-06 2.91973640e-06 2.54520296e-06
#  2.81041351e-07] , [9.32314588e-07 2.05037528e-06 5.10648651e-06 3.73061425e-06
#  2.58467663e-06]
# m=3 [2.61368624e-06 4.40197834e-06 2.34851902e-06 5.39384737e-06
#  2.16421466e-06] , [2.22059954e-06 4.11664358e-06 4.67880429e-06 4.18108007e-06
#  1.83014552e-06]
# m=4 [3.17914622e-06 2.24094361e-06 3.51385108e-06 2.24303320e-06
#  3.79156118e-06] , [3.38969483e-06 2.08396963e-06 3.77643251e-06 3.91774540e-06
#  1.50325238e-06]
# m=5 [2.87223074e-06 2.07942762e-06 4.63518676e-06 1.95769415e-06
#  7.95135581e-06] , [2.67550612e-06 3.22233971e-06 2.73935082e-06 3.38162658e-06
#  3.93052472e-06]
# m=10 [1.86283484e-06 2.72296762e-06 5.32137869e-06 2.17986298e-06
# ...

# %%
#Webspam Datensatz mit p = 2.0

# load all datasets
# %store -r Webspam
print("Webspam Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 2.0
p = 2.0
print("p = 2.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Webspam_v1_1 = compute_random_evaluations_probabilities(Webspam.X, m=1, p=p, rng=rng)
data_Webspam_v1_2 = compute_random_evaluations_probabilities(Webspam.X, m=2, p=p, rng=rng)
data_Webspam_v1_3 = compute_random_evaluations_probabilities(Webspam.X, m=3, p=p, rng=rng)
data_Webspam_v1_4 = compute_random_evaluations_probabilities(Webspam.X, m=4, p=p, rng=rng)
data_Webspam_v1_5 = compute_random_evaluations_probabilities(Webspam.X, m=5, p=p, rng=rng)
data_Webspam_v1_10 = compute_random_evaluations_probabilities(Webspam.X, m=10, p=p, rng=rng)
data_Webspam_v1_20 = compute_random_evaluations_probabilities(Webspam.X, m=20, p=p, rng=rng)
data_Webspam_v1_50 = compute_random_evaluations_probabilities(Webspam.X, m=50, p=p, rng=rng)
data_Webspam_v1_100 = compute_random_evaluations_probabilities(Webspam.X, m=100, p=p, rng=rng)
data_Webspam_v1_200 = compute_random_evaluations_probabilities(Webspam.X, m=200, p=p, rng=rng)
data_Webspam_v1_1000 = compute_random_evaluations_probabilities(Webspam.X, m=1000, p=p, rng=rng)
print("m=1",data_Webspam_v1_1[range(5)],",", data_Webspam_v1_1[-5:])
print("m=2",data_Webspam_v1_2[range(5)],",", data_Webspam_v1_2[-5:])
print("m=3",data_Webspam_v1_3[range(5)],",", data_Webspam_v1_3[-5:])
print("m=4",data_Webspam_v1_4[range(5)],",", data_Webspam_v1_4[-5:])
print("m=5",data_Webspam_v1_5[range(5)],",", data_Webspam_v1_5[-5:])
print("m=10",data_Webspam_v1_10[range(5)],",", data_Webspam_v1_10[-5:])
print("m=20",data_Webspam_v1_20[range(5)],",", data_Webspam_v1_20[-5:])
print("m=50",data_Webspam_v1_50[range(5)],",", data_Webspam_v1_50[-5:])
print("m=100",data_Webspam_v1_100[range(5)],",", data_Webspam_v1_100[-5:])
print("m=200",data_Webspam_v1_200[range(5)],",", data_Webspam_v1_200[-5:])
print("m=1000",data_Webspam_v1_1000[range(5)],",", data_Webspam_v1_1000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Webspam_v2_1 = compute_random_evaluations_probabilities_v2(Webspam.X, m=1, p=p, rng=rng)
data_Webspam_v2_2 = compute_random_evaluations_probabilities_v2(Webspam.X, m=2, p=p, rng=rng)
data_Webspam_v2_3 = compute_random_evaluations_probabilities_v2(Webspam.X, m=3, p=p, rng=rng)
data_Webspam_v2_4 = compute_random_evaluations_probabilities_v2(Webspam.X, m=4, p=p, rng=rng)
data_Webspam_v2_5 = compute_random_evaluations_probabilities_v2(Webspam.X, m=5, p=p, rng=rng)
data_Webspam_v2_10 = compute_random_evaluations_probabilities_v2(Webspam.X, m=10, p=p, rng=rng)
data_Webspam_v2_20 = compute_random_evaluations_probabilities_v2(Webspam.X, m=20, p=p, rng=rng)
data_Webspam_v2_50 = compute_random_evaluations_probabilities_v2(Webspam.X, m=50, p=p, rng=rng)
data_Webspam_v2_100 = compute_random_evaluations_probabilities_v2(Webspam.X, m=100, p=p, rng=rng)
data_Webspam_v2_200 = compute_random_evaluations_probabilities_v2(Webspam.X, m=200, p=p, rng=rng)
data_Webspam_v2_1000 = compute_random_evaluations_probabilities_v2(Webspam.X, m=1000, p=p, rng=rng)
print("m=1",data_Webspam_v2_1[range(5)],",", data_Webspam_v2_1[-5:])
print("m=2",data_Webspam_v2_2[range(5)],",", data_Webspam_v2_2[-5:])
print("m=3",data_Webspam_v2_3[range(5)],",", data_Webspam_v2_3[-5:])
print("m=4",data_Webspam_v2_4[range(5)],",", data_Webspam_v2_4[-5:])
print("m=5",data_Webspam_v2_5[range(5)],",", data_Webspam_v2_5[-5:])
print("m=10",data_Webspam_v2_10[range(5)],",", data_Webspam_v2_10[-5:])
print("m=20",data_Webspam_v2_20[range(5)],",", data_Webspam_v2_20[-5:])
print("m=50",data_Webspam_v2_50[range(5)],",", data_Webspam_v2_50[-5:])
print("m=100",data_Webspam_v2_100[range(5)],",", data_Webspam_v2_100[-5:])
print("m=200",data_Webspam_v2_200[range(5)],",", data_Webspam_v2_200[-5:])
print("m=1000",data_Webspam_v2_1000[range(5)],",", data_Webspam_v2_1000[-5:])
# Out:
# Webspam Datensatz
# p = 2.0
# Version 1
# m=1 [1.08446818e-10 2.21107498e-06 1.49174303e-06 2.53658964e-07
#  5.87329559e-06] , [3.64744275e-08 1.09439407e-10 8.87210102e-06 2.05213455e-07
#  3.18152647e-08]
# m=2 [1.27184705e-06 3.24691023e-07 1.02869814e-06 8.34800146e-07
#  1.00753967e-08] , [1.30271295e-07 5.84238158e-07 3.17110682e-06 2.95725550e-06
#  7.72643018e-07]
# m=3 [1.21771859e-06 3.42452406e-06 1.94362170e-06 6.64205552e-06
#  1.44691800e-06] , [1.27836396e-06 2.69636284e-06 3.15753453e-06 3.22421125e-06
#  7.33765449e-07]
# m=4 [2.03279552e-06 1.75828077e-06 2.97344897e-06 1.31074358e-06
#  4.42167956e-06] , [2.46901575e-06 1.23594097e-06 2.88840415e-06 2.82720233e-06
#  5.95715092e-07]
# m=5 [1.11201822e-06 7.18198229e-07 3.94538018e-06 6.12312939e-07
#  1.00088712e-05] , [1.13572589e-06 1.70763962e-06 1.60328194e-06 2.83963436e-06
#  2.70065782e-06]
# m=10 [6.01131788e-07 1.57924763e-06 5.00388193e-06 9.47062252e-07
# ...

# %%
#Covertype Datensatz mit p = 1.0

# load all datasets
# %store -r Covertype
print("Covertype Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 1.0
p = 1.0
print("p = 1.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Covertype_v1_1 = compute_random_evaluations_probabilities(Covertype.X, m=1, p=p, rng=rng)
data_Covertype_v1_2 = compute_random_evaluations_probabilities(Covertype.X, m=2, p=p, rng=rng)
data_Covertype_v1_3 = compute_random_evaluations_probabilities(Covertype.X, m=3, p=p, rng=rng)
data_Covertype_v1_4 = compute_random_evaluations_probabilities(Covertype.X, m=4, p=p, rng=rng)
data_Covertype_v1_5 = compute_random_evaluations_probabilities(Covertype.X, m=5, p=p, rng=rng)
data_Covertype_v1_10 = compute_random_evaluations_probabilities(Covertype.X, m=10, p=p, rng=rng)
data_Covertype_v1_20 = compute_random_evaluations_probabilities(Covertype.X, m=20, p=p, rng=rng)
data_Covertype_v1_50 = compute_random_evaluations_probabilities(Covertype.X, m=50, p=p, rng=rng)
data_Covertype_v1_100 = compute_random_evaluations_probabilities(Covertype.X, m=100, p=p, rng=rng)
data_Covertype_v1_200 = compute_random_evaluations_probabilities(Covertype.X, m=200, p=p, rng=rng)
data_Covertype_v1_1000 = compute_random_evaluations_probabilities(Covertype.X, m=1000, p=p, rng=rng)
print("m=1",data_Covertype_v1_1[range(5)],",", data_Covertype_v1_1[-5:])
print("m=2",data_Covertype_v1_2[range(5)],",", data_Covertype_v1_2[-5:])
print("m=3",data_Covertype_v1_3[range(5)],",", data_Covertype_v1_3[-5:])
print("m=4",data_Covertype_v1_4[range(5)],",", data_Covertype_v1_4[-5:])
print("m=5",data_Covertype_v1_5[range(5)],",", data_Covertype_v1_5[-5:])
print("m=10",data_Covertype_v1_10[range(5)],",", data_Covertype_v1_10[-5:])
print("m=20",data_Covertype_v1_20[range(5)],",", data_Covertype_v1_20[-5:])
print("m=50",data_Covertype_v1_50[range(5)],",", data_Covertype_v1_50[-5:])
print("m=100",data_Covertype_v1_100[range(5)],",", data_Covertype_v1_100[-5:])
print("m=200",data_Covertype_v1_200[range(5)],",", data_Covertype_v1_200[-5:])
print("m=1000",data_Covertype_v1_1000[range(5)],",", data_Covertype_v1_1000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Covertype_v2_1 = compute_random_evaluations_probabilities_v2(Covertype.X, m=1, p=p, rng=rng)
data_Covertype_v2_2 = compute_random_evaluations_probabilities_v2(Covertype.X, m=2, p=p, rng=rng)
data_Covertype_v2_3 = compute_random_evaluations_probabilities_v2(Covertype.X, m=3, p=p, rng=rng)
data_Covertype_v2_4 = compute_random_evaluations_probabilities_v2(Covertype.X, m=4, p=p, rng=rng)
data_Covertype_v2_5 = compute_random_evaluations_probabilities_v2(Covertype.X, m=5, p=p, rng=rng)
data_Covertype_v2_10 = compute_random_evaluations_probabilities_v2(Covertype.X, m=10, p=p, rng=rng)
data_Covertype_v2_20 = compute_random_evaluations_probabilities_v2(Covertype.X, m=20, p=p, rng=rng)
data_Covertype_v2_50 = compute_random_evaluations_probabilities_v2(Covertype.X, m=50, p=p, rng=rng)
data_Covertype_v2_100 = compute_random_evaluations_probabilities_v2(Covertype.X, m=100, p=p, rng=rng)
data_Covertype_v2_200 = compute_random_evaluations_probabilities_v2(Covertype.X, m=200, p=p, rng=rng)
data_Covertype_v2_1000 = compute_random_evaluations_probabilities_v2(Covertype.X, m=1000, p=p, rng=rng)
print("m=1",data_Covertype_v2_1[range(5)],",", data_Covertype_v2_1[-5:])
print("m=2",data_Covertype_v2_2[range(5)],",", data_Covertype_v2_2[-5:])
print("m=3",data_Covertype_v2_3[range(5)],",", data_Covertype_v2_3[-5:])
print("m=4",data_Covertype_v2_4[range(5)],",", data_Covertype_v2_4[-5:])
print("m=5",data_Covertype_v2_5[range(5)],",", data_Covertype_v2_5[-5:])
print("m=10",data_Covertype_v2_10[range(5)],",", data_Covertype_v2_10[-5:])
print("m=20",data_Covertype_v2_20[range(5)],",", data_Covertype_v2_20[-5:])
print("m=50",data_Covertype_v2_50[range(5)],",", data_Covertype_v2_50[-5:])
print("m=100",data_Covertype_v2_100[range(5)],",", data_Covertype_v2_100[-5:])
print("m=200",data_Covertype_v2_200[range(5)],",", data_Covertype_v2_200[-5:])
print("m=1000",data_Covertype_v2_1000[range(5)],",", data_Covertype_v2_1000[-5:])
# Out:
# Covertype Datensatz
# p = 1.0
# Version 1
# m=1 [3.23697447e-06 3.22078818e-06 8.48257528e-07 1.29749661e-06
#  2.89375154e-06] , [6.87162595e-07 6.10816347e-07 1.99359491e-07 2.89103275e-07
#  7.10695433e-07]
# m=2 [2.13039472e-06 2.08998166e-06 1.98501442e-06 2.08610382e-06
#  2.21142513e-06] , [7.44309070e-07 7.42978317e-07 7.09342407e-07 6.67422540e-07
#  6.43463670e-07]
# m=3 [3.86646245e-06 3.88092612e-06 2.49663039e-06 2.83711347e-06
#  3.85330182e-06] , [2.61063870e-06 2.63992151e-06 2.62786246e-06 2.58992195e-06
#  2.65185807e-06]
# m=4 [7.08493885e-07 7.97882555e-07 9.50134978e-07 1.27452922e-06
#  7.73476852e-07] , [1.29560381e-06 1.30027170e-06 1.22174443e-06 1.14327569e-06
#  1.19996883e-06]
# m=5 [3.48545240e-06 3.55224155e-06 3.46869451e-06 3.58689878e-06
#  3.62799329e-06] , [1.49436366e-06 1.46614783e-06 1.27803731e-06 1.14407681e-06
#  1.13008558e-06]
# m=10 [2.15760070e-06 2.21266137e-06 1.90280212e-06 1.94032713e-06
# ...

# %%
#Covertype Datensatz mit p = 2.0

# load all datasets
# %store -r Covertype
print("Covertype Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 2.0
p = 2.0
print("p = 2.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_Covertype_v1_1 = compute_random_evaluations_probabilities(Covertype.X, m=1, p=p, rng=rng)
data_Covertype_v1_2 = compute_random_evaluations_probabilities(Covertype.X, m=2, p=p, rng=rng)
data_Covertype_v1_3 = compute_random_evaluations_probabilities(Covertype.X, m=3, p=p, rng=rng)
data_Covertype_v1_4 = compute_random_evaluations_probabilities(Covertype.X, m=4, p=p, rng=rng)
data_Covertype_v1_5 = compute_random_evaluations_probabilities(Covertype.X, m=5, p=p, rng=rng)
data_Covertype_v1_10 = compute_random_evaluations_probabilities(Covertype.X, m=10, p=p, rng=rng)
data_Covertype_v1_20 = compute_random_evaluations_probabilities(Covertype.X, m=20, p=p, rng=rng)
data_Covertype_v1_50 = compute_random_evaluations_probabilities(Covertype.X, m=50, p=p, rng=rng)
data_Covertype_v1_100 = compute_random_evaluations_probabilities(Covertype.X, m=100, p=p, rng=rng)
data_Covertype_v1_200 = compute_random_evaluations_probabilities(Covertype.X, m=200, p=p, rng=rng)
data_Covertype_v1_1000 = compute_random_evaluations_probabilities(Covertype.X, m=1000, p=p, rng=rng)
print("m=1",data_Covertype_v1_1[range(5)],",", data_Covertype_v1_1[-5:])
print("m=2",data_Covertype_v1_2[range(5)],",", data_Covertype_v1_2[-5:])
print("m=3",data_Covertype_v1_3[range(5)],",", data_Covertype_v1_3[-5:])
print("m=4",data_Covertype_v1_4[range(5)],",", data_Covertype_v1_4[-5:])
print("m=5",data_Covertype_v1_5[range(5)],",", data_Covertype_v1_5[-5:])
print("m=10",data_Covertype_v1_10[range(5)],",", data_Covertype_v1_10[-5:])
print("m=20",data_Covertype_v1_20[range(5)],",", data_Covertype_v1_20[-5:])
print("m=50",data_Covertype_v1_50[range(5)],",", data_Covertype_v1_50[-5:])
print("m=100",data_Covertype_v1_100[range(5)],",", data_Covertype_v1_100[-5:])
print("m=200",data_Covertype_v1_200[range(5)],",", data_Covertype_v1_200[-5:])
print("m=1000",data_Covertype_v1_1000[range(5)],",", data_Covertype_v1_1000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_Covertype_v2_1 = compute_random_evaluations_probabilities_v2(Covertype.X, m=1, p=p, rng=rng)
data_Covertype_v2_2 = compute_random_evaluations_probabilities_v2(Covertype.X, m=2, p=p, rng=rng)
data_Covertype_v2_3 = compute_random_evaluations_probabilities_v2(Covertype.X, m=3, p=p, rng=rng)
data_Covertype_v2_4 = compute_random_evaluations_probabilities_v2(Covertype.X, m=4, p=p, rng=rng)
data_Covertype_v2_5 = compute_random_evaluations_probabilities_v2(Covertype.X, m=5, p=p, rng=rng)
data_Covertype_v2_10 = compute_random_evaluations_probabilities_v2(Covertype.X, m=10, p=p, rng=rng)
data_Covertype_v2_20 = compute_random_evaluations_probabilities_v2(Covertype.X, m=20, p=p, rng=rng)
data_Covertype_v2_50 = compute_random_evaluations_probabilities_v2(Covertype.X, m=50, p=p, rng=rng)
data_Covertype_v2_100 = compute_random_evaluations_probabilities_v2(Covertype.X, m=100, p=p, rng=rng)
data_Covertype_v2_200 = compute_random_evaluations_probabilities_v2(Covertype.X, m=200, p=p, rng=rng)
data_Covertype_v2_1000 = compute_random_evaluations_probabilities_v2(Covertype.X, m=1000, p=p, rng=rng)
print("m=1",data_Covertype_v2_1[range(5)],",", data_Covertype_v2_1[-5:])
print("m=2",data_Covertype_v2_2[range(5)],",", data_Covertype_v2_2[-5:])
print("m=3",data_Covertype_v2_3[range(5)],",", data_Covertype_v2_3[-5:])
print("m=4",data_Covertype_v2_4[range(5)],",", data_Covertype_v2_4[-5:])
print("m=5",data_Covertype_v2_5[range(5)],",", data_Covertype_v2_5[-5:])
print("m=10",data_Covertype_v2_10[range(5)],",", data_Covertype_v2_10[-5:])
print("m=20",data_Covertype_v2_20[range(5)],",", data_Covertype_v2_20[-5:])
print("m=50",data_Covertype_v2_50[range(5)],",", data_Covertype_v2_50[-5:])
print("m=100",data_Covertype_v2_100[range(5)],",", data_Covertype_v2_100[-5:])
print("m=200",data_Covertype_v2_200[range(5)],",", data_Covertype_v2_200[-5:])
print("m=1000",data_Covertype_v2_1000[range(5)],",", data_Covertype_v2_1000[-5:])
# Out:
# Covertype Datensatz
# p = 2.0
# Version 1
# m=1 [3.70624275e-06 3.66926974e-06 2.54513461e-07 5.95480812e-07
#  2.96195046e-06] , [1.67022251e-07 1.31970425e-07 1.40581814e-08 2.95638735e-08
#  1.78657956e-07]
# m=2 [2.00079575e-06 1.91823374e-06 1.79701074e-06 2.42859630e-06
#  2.13770767e-06] , [2.25169048e-07 2.23161076e-07 1.98020042e-07 1.98716927e-07
#  1.91139896e-07]
# m=3 [5.97601066e-06 6.13014396e-06 2.71992385e-06 3.99497628e-06
#  5.99041176e-06] , [2.63801240e-06 2.69200796e-06 2.75901475e-06 2.88635123e-06
#  2.96697662e-06]
# m=4 [2.18809358e-07 2.49337589e-07 4.61691132e-07 8.03004873e-07
#  2.34943334e-07] , [6.51384210e-07 6.58507951e-07 5.77395217e-07 5.09771293e-07
#  5.57640638e-07]
# m=5 [6.03600630e-06 6.12511115e-06 5.89719843e-06 6.36199138e-06
#  6.28940076e-06] , [1.11842442e-06 1.08749848e-06 8.64289131e-07 6.62561297e-07
#  6.77651847e-07]
# m=10 [2.57700921e-06 2.76405772e-06 1.87539274e-06 2.77610988e-06
# ...

# %%
#KDDCup Datensatz mit p = 1.0

# load all datasets
# %store -r KDDCup
print("KDDCup Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 1.0
p = 1.0
print("p = 1.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_KDDCup_v1_1 = compute_random_evaluations_probabilities(KDDCup.X, m=1, p=p, rng=rng)
data_KDDCup_v1_2 = compute_random_evaluations_probabilities(KDDCup.X, m=2, p=p, rng=rng)
data_KDDCup_v1_3 = compute_random_evaluations_probabilities(KDDCup.X, m=3, p=p, rng=rng)
data_KDDCup_v1_4 = compute_random_evaluations_probabilities(KDDCup.X, m=4, p=p, rng=rng)
data_KDDCup_v1_5 = compute_random_evaluations_probabilities(KDDCup.X, m=5, p=p, rng=rng)
data_KDDCup_v1_10 = compute_random_evaluations_probabilities(KDDCup.X, m=10, p=p, rng=rng)
data_KDDCup_v1_20 = compute_random_evaluations_probabilities(KDDCup.X, m=20, p=p, rng=rng)
data_KDDCup_v1_50 = compute_random_evaluations_probabilities(KDDCup.X, m=50, p=p, rng=rng)
data_KDDCup_v1_100 = compute_random_evaluations_probabilities(KDDCup.X, m=100, p=p, rng=rng)
data_KDDCup_v1_200 = compute_random_evaluations_probabilities(KDDCup.X, m=200, p=p, rng=rng)
data_KDDCup_v1_1000 = compute_random_evaluations_probabilities(KDDCup.X, m=1000, p=p, rng=rng)
print("m=1",data_KDDCup_v1_1[range(5)],",", data_KDDCup_v1_1[-5:])
print("m=2",data_KDDCup_v1_2[range(5)],",", data_KDDCup_v1_2[-5:])
print("m=3",data_KDDCup_v1_3[range(5)],",", data_KDDCup_v1_3[-5:])
print("m=4",data_KDDCup_v1_4[range(5)],",", data_KDDCup_v1_4[-5:])
print("m=5",data_KDDCup_v1_5[range(5)],",", data_KDDCup_v1_5[-5:])
print("m=10",data_KDDCup_v1_10[range(5)],",", data_KDDCup_v1_10[-5:])
print("m=20",data_KDDCup_v1_20[range(5)],",", data_KDDCup_v1_20[-5:])
print("m=50",data_KDDCup_v1_50[range(5)],",", data_KDDCup_v1_50[-5:])
print("m=100",data_KDDCup_v1_100[range(5)],",", data_KDDCup_v1_100[-5:])
print("m=200",data_KDDCup_v1_200[range(5)],",", data_KDDCup_v1_200[-5:])
print("m=1000",data_KDDCup_v1_1000[range(5)],",", data_KDDCup_v1_1000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_KDDCup_v2_1 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=1, p=p, rng=rng)
data_KDDCup_v2_2 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=2, p=p, rng=rng)
data_KDDCup_v2_3 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=3, p=p, rng=rng)
data_KDDCup_v2_4 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=4, p=p, rng=rng)
data_KDDCup_v2_5 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=5, p=p, rng=rng)
data_KDDCup_v2_10 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=10, p=p, rng=rng)
data_KDDCup_v2_20 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=20, p=p, rng=rng)
data_KDDCup_v2_50 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=50, p=p, rng=rng)
data_KDDCup_v2_100 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=100, p=p, rng=rng)
data_KDDCup_v2_200 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=200, p=p, rng=rng)
data_KDDCup_v2_1000 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=1000, p=p, rng=rng)
print("m=1",data_KDDCup_v2_1[range(5)],",", data_KDDCup_v2_1[-5:])
print("m=2",data_KDDCup_v2_2[range(5)],",", data_KDDCup_v2_2[-5:])
print("m=3",data_KDDCup_v2_3[range(5)],",", data_KDDCup_v2_3[-5:])
print("m=4",data_KDDCup_v2_4[range(5)],",", data_KDDCup_v2_4[-5:])
print("m=5",data_KDDCup_v2_5[range(5)],",", data_KDDCup_v2_5[-5:])
print("m=10",data_KDDCup_v2_10[range(5)],",", data_KDDCup_v2_10[-5:])
print("m=20",data_KDDCup_v2_20[range(5)],",", data_KDDCup_v2_20[-5:])
print("m=50",data_KDDCup_v2_50[range(5)],",", data_KDDCup_v2_50[-5:])
print("m=100",data_KDDCup_v2_100[range(5)],",", data_KDDCup_v2_100[-5:])
print("m=200",data_KDDCup_v2_200[range(5)],",", data_KDDCup_v2_200[-5:])
print("m=1000",data_KDDCup_v2_1000[range(5)],",", data_KDDCup_v2_1000[-5:])
# Out:
# KDDCup Datensatz
# p = 1.0
# Version 1
# m=1 [4.17209904e-07 5.07033978e-07 4.67877674e-07 4.91744174e-07
#  4.74091451e-07] , [1.07250720e-07 6.25843792e-07 2.94016048e-07 2.64225977e-07
#  4.86057299e-07]
# m=2 [3.71443798e-06 3.48072599e-06 3.24052381e-06 3.00644358e-06
#  2.76970123e-06] , [2.05695307e-06 1.27235194e-06 1.29565106e-06 1.02375470e-06
#  1.41690912e-06]
# m=3 [1.81767951e-06 1.84717079e-06 1.88752503e-06 1.93598486e-06
#  1.97666348e-06] , [2.70961302e-06 9.16475274e-07 8.43712794e-07 1.53258798e-06
#  1.20159819e-06]
# m=4 [2.72388010e-06 2.62227883e-06 2.54107938e-06 2.44891701e-06
#  2.36240888e-06] , [1.66337982e-06 1.66120133e-06 1.59231222e-06 1.74419401e-06
#  1.87899830e-06]
# m=5 [4.48901868e-06 4.29315364e-06 4.10699084e-06 3.93116813e-06
#  3.74861690e-06] , [2.55441169e-06 2.73642487e-06 2.00431126e-06 2.09638746e-06
#  2.43636961e-06]
# m=10 [4.00895186e-06 3.83907002e-06 3.72076841e-06 3.58592056e-06
# ...

# %%
#KDDCup Datensatz mit p = 2.0

# load all datasets
# %store -r KDDCup
print("KDDCup Datensatz")

from efficient_probit_regression.sampling import compute_random_evaluations_probabilities, compute_random_evaluations_probabilities_v2

rng = 2026

#for p = 2.0
p = 2.0
print("p = 2.0")

#compute_random_evaluations_probabilities
print("Version 1")
data_KDDCup_v1_1 = compute_random_evaluations_probabilities(KDDCup.X, m=1, p=p, rng=rng)
data_KDDCup_v1_2 = compute_random_evaluations_probabilities(KDDCup.X, m=2, p=p, rng=rng)
data_KDDCup_v1_3 = compute_random_evaluations_probabilities(KDDCup.X, m=3, p=p, rng=rng)
data_KDDCup_v1_4 = compute_random_evaluations_probabilities(KDDCup.X, m=4, p=p, rng=rng)
data_KDDCup_v1_5 = compute_random_evaluations_probabilities(KDDCup.X, m=5, p=p, rng=rng)
data_KDDCup_v1_10 = compute_random_evaluations_probabilities(KDDCup.X, m=10, p=p, rng=rng)
data_KDDCup_v1_20 = compute_random_evaluations_probabilities(KDDCup.X, m=20, p=p, rng=rng)
data_KDDCup_v1_50 = compute_random_evaluations_probabilities(KDDCup.X, m=50, p=p, rng=rng)
data_KDDCup_v1_100 = compute_random_evaluations_probabilities(KDDCup.X, m=100, p=p, rng=rng)
data_KDDCup_v1_200 = compute_random_evaluations_probabilities(KDDCup.X, m=200, p=p, rng=rng)
data_KDDCup_v1_1000 = compute_random_evaluations_probabilities(KDDCup.X, m=1000, p=p, rng=rng)
print("m=1",data_KDDCup_v1_1[range(5)],",", data_KDDCup_v1_1[-5:])
print("m=2",data_KDDCup_v1_2[range(5)],",", data_KDDCup_v1_2[-5:])
print("m=3",data_KDDCup_v1_3[range(5)],",", data_KDDCup_v1_3[-5:])
print("m=4",data_KDDCup_v1_4[range(5)],",", data_KDDCup_v1_4[-5:])
print("m=5",data_KDDCup_v1_5[range(5)],",", data_KDDCup_v1_5[-5:])
print("m=10",data_KDDCup_v1_10[range(5)],",", data_KDDCup_v1_10[-5:])
print("m=20",data_KDDCup_v1_20[range(5)],",", data_KDDCup_v1_20[-5:])
print("m=50",data_KDDCup_v1_50[range(5)],",", data_KDDCup_v1_50[-5:])
print("m=100",data_KDDCup_v1_100[range(5)],",", data_KDDCup_v1_100[-5:])
print("m=200",data_KDDCup_v1_200[range(5)],",", data_KDDCup_v1_200[-5:])
print("m=1000",data_KDDCup_v1_1000[range(5)],",", data_KDDCup_v1_1000[-5:])

#compute_random_evaluations_probabilities_v2
print("Version 2")
data_KDDCup_v2_1 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=1, p=p, rng=rng)
data_KDDCup_v2_2 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=2, p=p, rng=rng)
data_KDDCup_v2_3 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=3, p=p, rng=rng)
data_KDDCup_v2_4 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=4, p=p, rng=rng)
data_KDDCup_v2_5 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=5, p=p, rng=rng)
data_KDDCup_v2_10 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=10, p=p, rng=rng)
data_KDDCup_v2_20 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=20, p=p, rng=rng)
data_KDDCup_v2_50 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=50, p=p, rng=rng)
data_KDDCup_v2_100 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=100, p=p, rng=rng)
data_KDDCup_v2_200 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=200, p=p, rng=rng)
data_KDDCup_v2_1000 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=1000, p=p, rng=rng)
print("m=1",data_KDDCup_v2_1[range(5)],",", data_KDDCup_v2_1[-5:])
print("m=2",data_KDDCup_v2_2[range(5)],",", data_KDDCup_v2_2[-5:])
print("m=3",data_KDDCup_v2_3[range(5)],",", data_KDDCup_v2_3[-5:])
print("m=4",data_KDDCup_v2_4[range(5)],",", data_KDDCup_v2_4[-5:])
print("m=5",data_KDDCup_v2_5[range(5)],",", data_KDDCup_v2_5[-5:])
print("m=10",data_KDDCup_v2_10[range(5)],",", data_KDDCup_v2_10[-5:])
print("m=20",data_KDDCup_v2_20[range(5)],",", data_KDDCup_v2_20[-5:])
print("m=50",data_KDDCup_v2_50[range(5)],",", data_KDDCup_v2_50[-5:])
print("m=100",data_KDDCup_v2_100[range(5)],",", data_KDDCup_v2_100[-5:])
print("m=200",data_KDDCup_v2_200[range(5)],",", data_KDDCup_v2_200[-5:])
print("m=1000",data_KDDCup_v2_1000[range(5)],",", data_KDDCup_v2_1000[-5:])
# Out:
# KDDCup Datensatz
# p = 2.0
# Version 1
# m=1 [4.81347777e-08 7.10925150e-08 6.05360940e-08 6.68695187e-08
#  6.21547037e-08] , [3.18090123e-09 1.08313265e-07 2.39051693e-08 1.93063767e-08
#  6.53318100e-08]
# m=2 [2.71660433e-06 2.38607402e-06 2.07266003e-06 1.79342336e-06
#  1.53680822e-06] , [8.79161096e-07 3.72704849e-07 7.22942143e-07 4.53206401e-07
#  5.74171126e-07]
# m=3 [1.03181126e-06 9.31570141e-07 8.77148892e-07 8.37266729e-07
#  8.05688525e-07] , [1.44163191e-06 3.01216656e-07 1.38525889e-07 4.87401928e-07
#  2.85967989e-07]
# m=4 [1.16077950e-06 1.07291688e-06 9.98196357e-07 9.29239387e-07
#  8.65080540e-07] , [2.81561655e-07 8.72412666e-07 5.22553193e-07 5.59888336e-07
#  7.43529764e-07]
# m=5 [2.39749269e-06 2.24505027e-06 2.08788304e-06 1.93106224e-06
#  1.78402220e-06] , [8.64569853e-07 9.40931624e-07 6.19258078e-07 6.51815095e-07
#  7.28287368e-07]
# m=10 [2.31228754e-06 2.19116039e-06 2.05848230e-06 1.91969448e-06
# ...
