# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Example2D Datensatz
# %store -r Example2D
print("Example2D Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Example2D_5 = compute_random_evaluations_probabilities_v2(Example2D.X, m=5, p=i, rng=rng)
    data_Example2D_10 = compute_random_evaluations_probabilities_v2(Example2D.X, m=10, p=i, rng=rng)
    data_Example2D_50 = compute_random_evaluations_probabilities_v2(Example2D.X, m=50, p=i, rng=rng)
    data_Example2D_100 = compute_random_evaluations_probabilities_v2(Example2D.X, m=100, p=i, rng=rng)
    data_Example2D_500 = compute_random_evaluations_probabilities_v2(Example2D.X, m=500, p=i, rng=rng)
    data_Example2D_1000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=1000, p=i, rng=rng)
    data_Example2D_5000 = compute_random_evaluations_probabilities_v2(Example2D.X, m=5000, p=i, rng=rng)
    
    data_Example2D_Vergleich_5_10 = np.maximum(data_Example2D_5/data_Example2D_10, data_Example2D_10/data_Example2D_5)
    data_Example2D_Vergleich_10_50 = np.maximum(data_Example2D_10/data_Example2D_50, data_Example2D_50/data_Example2D_10)
    data_Example2D_Vergleich_50_100 = np.maximum(data_Example2D_50/data_Example2D_100, data_Example2D_100/data_Example2D_50)
    data_Example2D_Vergleich_100_500 = np.maximum(data_Example2D_100/data_Example2D_500, data_Example2D_500/data_Example2D_100)
    data_Example2D_Vergleich_500_1000 = np.maximum(data_Example2D_500/data_Example2D_1000, data_Example2D_1000/data_Example2D_500)
    data_Example2D_Vergleich_1000_5000 = np.maximum(data_Example2D_1000/data_Example2D_5000, data_Example2D_5000/data_Example2D_1000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Example2D_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Example2D_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Example2D_Vergleich_50_100))
    print("Vergleich m=100 und m=500")
    print(max(data_Example2D_Vergleich_100_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Example2D_Vergleich_500_1000))
    print("Vergleich m=1000 und m=5000")
    print(max(data_Example2D_Vergleich_1000_5000))
    print("")
# Out:
# Example2D Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 14.774737422371313
# Vergleich m=10 und m=50
# 1.612262802391592
# Vergleich m=50 und m=100
# 1.22800392779003
# Vergleich m=100 und m=500
# 1.0703128333868783
# Vergleich m=500 und m=1000
# 1.0679065893688524
# Vergleich m=1000 und m=5000
# 1.0597093135284243
#
# p =  1.3
# Vergleich m=5 und m=10
# 32.47398721820397
# Vergleich m=10 und m=50
# 1.8216655721659258
# Vergleich m=50 und m=100
# 1.26955985037225
# Vergleich m=100 und m=500
# 1.05902552381407
# Vergleich m=500 und m=1000
# 1.0810138090957404
# Vergleich m=1000 und m=5000
# 1.0701654405473422
#
# p =  1.5
# Vergleich m=5 und m=10
# 54.66007244507667
# Vergleich m=10 und m=50
# 2.1471955676801264
# Vergleich m=50 und m=100
# 1.307302845105593
# Vergleich m=100 und m=500
# 1.0639253559389115
# Vergleich m=500 und m=1000
# 1.0881457724398043
# Vergleich m=1000 und m=5000
# 1.0760953315235675
#
# p =  1.7
# Vergleich m=5 und m=10
# 91.83628050014079
# ...

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Iris Datensatz
# %store -r Iris
print("Iris Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Iris_5 = compute_random_evaluations_probabilities_v2(Iris.X, m=5, p=i, rng=rng)
    data_Iris_10 = compute_random_evaluations_probabilities_v2(Iris.X, m=10, p=i, rng=rng)
    data_Iris_50 = compute_random_evaluations_probabilities_v2(Iris.X, m=50, p=i, rng=rng)
    data_Iris_100 = compute_random_evaluations_probabilities_v2(Iris.X, m=100, p=i, rng=rng)
    data_Iris_500 = compute_random_evaluations_probabilities_v2(Iris.X, m=500, p=i, rng=rng)
    data_Iris_1000 = compute_random_evaluations_probabilities_v2(Iris.X, m=1000, p=i, rng=rng)
    data_Iris_5000 = compute_random_evaluations_probabilities_v2(Iris.X, m=5000, p=i, rng=rng)
    
    data_Iris_Vergleich_5_10 = np.maximum(data_Iris_5/data_Iris_10, data_Iris_10/data_Iris_5)
    data_Iris_Vergleich_10_50 = np.maximum(data_Iris_10/data_Iris_50, data_Iris_50/data_Iris_10)
    data_Iris_Vergleich_50_100 = np.maximum(data_Iris_50/data_Iris_100, data_Iris_100/data_Iris_50)
    data_Iris_Vergleich_100_500 = np.maximum(data_Iris_100/data_Iris_500, data_Iris_500/data_Iris_100)
    data_Iris_Vergleich_500_1000 = np.maximum(data_Iris_500/data_Iris_1000, data_Iris_1000/data_Iris_500)
    data_Iris_Vergleich_1000_5000 = np.maximum(data_Iris_1000/data_Iris_5000, data_Iris_5000/data_Iris_1000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Iris_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Iris_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Iris_Vergleich_50_100))
    print("Vergleich m=100 und m=500")
    print(max(data_Iris_Vergleich_100_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Iris_Vergleich_500_1000))
    print("Vergleich m=1000 und m=10000")
    print(max(data_Iris_Vergleich_1000_5000))
    print("")
# Out:
# Iris Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 2.2088239070221194
# Vergleich m=10 und m=50
# 2.4766759326210903
# Vergleich m=50 und m=100
# 1.596084699516401
# Vergleich m=100 und m=500
# 1.1420709287248645
# Vergleich m=500 und m=1000
# 1.0740908334872643
# Vergleich m=1000 und m=10000
# 1.0504680795099317
#
# p =  1.3
# Vergleich m=5 und m=10
# 2.837233403830839
# Vergleich m=10 und m=50
# 3.1362182860150076
# Vergleich m=50 und m=100
# 1.8652879712252892
# Vergleich m=100 und m=500
# 1.177832118401137
# Vergleich m=500 und m=1000
# 1.0933686368703792
# Vergleich m=1000 und m=10000
# 1.057315477239269
#
# p =  1.5
# Vergleich m=5 und m=10
# 3.4209976460221645
# Vergleich m=10 und m=50
# 3.6504672608493816
# Vergleich m=50 und m=100
# 2.065558132278344
# Vergleich m=100 und m=500
# 1.2030021316520767
# Vergleich m=500 und m=1000
# 1.110467053615838
# Vergleich m=1000 und m=10000
# 1.0616257124735433
#
# p =  1.7
# Vergleich m=5 und m=10
# 4.140099248869755
# ...

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Webspam Datensatz
# %store -r Webspam
print("Webspam Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Webspam_5 = compute_random_evaluations_probabilities_v2(Webspam.X, m=5, p=i, rng=rng)
    data_Webspam_10 = compute_random_evaluations_probabilities_v2(Webspam.X, m=10, p=i, rng=rng)
    data_Webspam_50 = compute_random_evaluations_probabilities_v2(Webspam.X, m=50, p=i, rng=rng)
    data_Webspam_100 = compute_random_evaluations_probabilities_v2(Webspam.X, m=100, p=i, rng=rng)
    data_Webspam_500 = compute_random_evaluations_probabilities_v2(Webspam.X, m=500, p=i, rng=rng)
    data_Webspam_1000 = compute_random_evaluations_probabilities_v2(Webspam.X, m=1000, p=i, rng=rng)
    data_Webspam_5000 = compute_random_evaluations_probabilities_v2(Webspam.X, m=5000, p=i, rng=rng)
    
    data_Webspam_Vergleich_5_10 = np.maximum(data_Webspam_5/data_Webspam_10, data_Webspam_10/data_Webspam_5)
    data_Webspam_Vergleich_10_50 = np.maximum(data_Webspam_10/data_Webspam_50, data_Webspam_50/data_Webspam_10)
    data_Webspam_Vergleich_50_100 = np.maximum(data_Webspam_50/data_Webspam_100, data_Webspam_100/data_Webspam_50)
    data_Webspam_Vergleich_100_500 = np.maximum(data_Webspam_100/data_Webspam_500, data_Webspam_500/data_Webspam_100)
    data_Webspam_Vergleich_500_1000 = np.maximum(data_Webspam_500/data_Webspam_1000, data_Webspam_1000/data_Webspam_500)
    data_Webspam_Vergleich_1000_5000 = np.maximum(data_Webspam_1000/data_Webspam_5000, data_Webspam_5000/data_Webspam_1000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Webspam_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Webspam_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Webspam_Vergleich_50_100))
    print("Vergleich m=100 und m=500")
    print(max(data_Webspam_Vergleich_100_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Webspam_Vergleich_500_1000))
    print("Vergleich m=1000 und m=5000")
    print(max(data_Webspam_Vergleich_1000_5000))
    print("")
# Out:
# Webspam Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 20.155770639491617
# Vergleich m=10 und m=50
# 10.11344876474238
# Vergleich m=50 und m=100
# 2.0066288032031383
# Vergleich m=100 und m=500
# 1.515802869695959
# Vergleich m=500 und m=1000
# 1.2699877580324814
# Vergleich m=1000 und m=5000
# 1.1371701100206282
#
# p =  1.3
# Vergleich m=5 und m=10
# 54.94898296222634
# Vergleich m=10 und m=50
# 19.24209042013934
# Vergleich m=50 und m=100
# 2.472651317043685
# Vergleich m=100 und m=500
# 1.698784146474452
# Vergleich m=500 und m=1000
# 1.3590288450295087
# Vergleich m=1000 und m=5000
# 1.1698760019653311
#
# p =  1.5
# Vergleich m=5 und m=10
# 112.25199787349763
# Vergleich m=10 und m=50
# 28.89331679215973
# Vergleich m=50 und m=100
# 2.8745515243767294
# Vergleich m=100 und m=500
# 1.8318076158020575
# Vergleich m=500 und m=1000
# 1.4192282105328027
# Vergleich m=1000 und m=5000
# 1.1970033321544646
#
# p =  1.7
# Vergleich m=5 und m=10
# 232.4086237409786
# ...

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#KDDCup Datensatz
# %store -r KDDCup
print("KDDCup Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_KDDCup_5 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=5, p=i, rng=rng)
    data_KDDCup_10 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=10, p=i, rng=rng)
    data_KDDCup_50 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=50, p=i, rng=rng)
    data_KDDCup_100 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=100, p=i, rng=rng)
    data_KDDCup_500 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=500, p=i, rng=rng)
    data_KDDCup_1000 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=1000, p=i, rng=rng)
    data_KDDCup_5000 = compute_random_evaluations_probabilities_v2(KDDCup.X, m=5000, p=i, rng=rng)
    
    data_KDDCup_Vergleich_5_10 = np.maximum(data_KDDCup_5/data_KDDCup_10, data_KDDCup_10/data_KDDCup_5)
    data_KDDCup_Vergleich_10_50 = np.maximum(data_KDDCup_10/data_KDDCup_50, data_KDDCup_50/data_KDDCup_10)
    data_KDDCup_Vergleich_50_100 = np.maximum(data_KDDCup_50/data_KDDCup_100, data_KDDCup_100/data_KDDCup_50)
    data_KDDCup_Vergleich_100_500 = np.maximum(data_KDDCup_100/data_KDDCup_500, data_KDDCup_500/data_KDDCup_100)
    data_KDDCup_Vergleich_500_1000 = np.maximum(data_KDDCup_500/data_KDDCup_1000, data_KDDCup_1000/data_KDDCup_500)
    data_KDDCup_Vergleich_1000_5000 = np.maximum(data_KDDCup_1000/data_KDDCup_5000, data_KDDCup_5000/data_KDDCup_1000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_KDDCup_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_KDDCup_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_KDDCup_Vergleich_50_100))
    print("Vergleich m=100 und m=500")
    print(max(data_KDDCup_Vergleich_100_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_KDDCup_Vergleich_500_1000))
    print("Vergleich m=1000 und m=5000")
    print(max(data_KDDCup_Vergleich_1000_5000))
    print("")
# Out:
# KDDCup Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 6.07566520228885
# Vergleich m=10 und m=50
# 3.5166619334972284
# Vergleich m=50 und m=100
# 1.6046074446855791
# Vergleich m=100 und m=500
# 1.3610018073262367
# Vergleich m=500 und m=1000
# 1.1838018030099384
# Vergleich m=1000 und m=5000
# 1.167208273217389
#
# p =  1.3
# Vergleich m=5 und m=10
# 9.509912025301562
# Vergleich m=10 und m=50
# 5.399950381456289
# Vergleich m=50 und m=100
# 1.8305118181469417
# Vergleich m=100 und m=500
# 1.5064907838136483
# Vergleich m=500 und m=1000
# 1.2290356562672426
# Vergleich m=1000 und m=5000
# 1.2254470365694434
#
# p =  1.5
# Vergleich m=5 und m=10
# 13.880898110598455
# Vergleich m=10 und m=50
# 7.18390091567602
# Vergleich m=50 und m=100
# 1.9463662522309475
# Vergleich m=100 und m=500
# 1.60272721040067
# Vergleich m=500 und m=1000
# 1.2603998761572366
# Vergleich m=1000 und m=5000
# 1.26701819543567
#
# p =  1.7
# Vergleich m=5 und m=10
# 20.48616265118357
# ...

# %%
import numpy as np
from efficient_probit_regression.sampling import compute_random_evaluations_probabilities_v2

#Covertype Datensatz
# %store -r Covertype
print("Covertype Datensatz")
print("")
rng = 2026
p = [1.0, 1.3, 1.5, 1.7, 2.0]

for i in p:
    print("p = ", i)
    
    #compute_random_evaluations_probabilities
    data_Covertype_5 = compute_random_evaluations_probabilities_v2(Covertype.X, m=5, p=i, rng=rng)
    data_Covertype_10 = compute_random_evaluations_probabilities_v2(Covertype.X, m=10, p=i, rng=rng)
    data_Covertype_50 = compute_random_evaluations_probabilities_v2(Covertype.X, m=50, p=i, rng=rng)
    data_Covertype_100 = compute_random_evaluations_probabilities_v2(Covertype.X, m=100, p=i, rng=rng)
    data_Covertype_500 = compute_random_evaluations_probabilities_v2(Covertype.X, m=500, p=i, rng=rng)
    data_Covertype_1000 = compute_random_evaluations_probabilities_v2(Covertype.X, m=1000, p=i, rng=rng)
    data_Covertype_5000 = compute_random_evaluations_probabilities_v2(Covertype.X, m=5000, p=i, rng=rng)
    
    data_Covertype_Vergleich_5_10 = np.maximum(data_Covertype_5/data_Covertype_10, data_Covertype_10/data_Covertype_5)
    data_Covertype_Vergleich_10_50 = np.maximum(data_Covertype_10/data_Covertype_50, data_Covertype_50/data_Covertype_10)
    data_Covertype_Vergleich_50_100 = np.maximum(data_Covertype_50/data_Covertype_100, data_Covertype_100/data_Covertype_50)
    data_Covertype_Vergleich_100_500 = np.maximum(data_Covertype_100/data_Covertype_500, data_Covertype_500/data_Covertype_100)
    data_Covertype_Vergleich_500_1000 = np.maximum(data_Covertype_500/data_Covertype_1000, data_Covertype_1000/data_Covertype_500)
    data_Covertype_Vergleich_1000_5000 = np.maximum(data_Covertype_1000/data_Covertype_5000, data_Covertype_5000/data_Covertype_1000)
    
    print("Vergleich m=5 und m=10")
    print(max(data_Covertype_Vergleich_5_10))
    print("Vergleich m=10 und m=50")
    print(max(data_Covertype_Vergleich_10_50))
    print("Vergleich m=50 und m=100")
    print(max(data_Covertype_Vergleich_50_100))
    print("Vergleich m=200 und m=500")
    print(max(data_Covertype_Vergleich_100_500))
    print("Vergleich m=500 und m=1000")
    print(max(data_Covertype_Vergleich_500_1000))
    print("Vergleich m=1000 und m=5000")
    print(max(data_Covertype_Vergleich_1000_5000))
    print("")
# Out:
# Covertype Datensatz
#
# p =  1.0
# Vergleich m=5 und m=10
# 41.51702018513106
# Vergleich m=10 und m=50
# 5.893587036848265
# Vergleich m=50 und m=100
# 1.6715709596741175
# Vergleich m=200 und m=500
# 1.4163144207108571
# Vergleich m=500 und m=1000
# 1.1754958336123364
# Vergleich m=1000 und m=5000
# 1.106319549866106
#
# p =  1.3
# Vergleich m=5 und m=10
# 134.3772341394514
# Vergleich m=10 und m=50
# 11.166010369127402
# Vergleich m=50 und m=100
# 1.8538127622087996
# Vergleich m=200 und m=500
# 1.5731920277041458
# Vergleich m=500 und m=1000
# 1.233689308244009
# Vergleich m=1000 und m=5000
# 1.1358960574035868
#
# p =  1.5
# Vergleich m=5 und m=10
# 296.93366174587015
# Vergleich m=10 und m=50
# 17.311734446634006
# Vergleich m=50 und m=100
# 2.0106850917095804
# Vergleich m=200 und m=500
# 1.6917692337562122
# Vergleich m=500 und m=1000
# 1.2813711127295735
# Vergleich m=1000 und m=5000
# 1.155575118941146
#
# p =  1.7
# Vergleich m=5 und m=10
# 660.9019483557778
# ...
