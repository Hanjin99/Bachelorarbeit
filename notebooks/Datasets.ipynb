# %%
# load and save all datasets

from efficient_probit_regression.datasets import Webspam
Webspam = Webspam()
Webspam.download_dataset()
Webspam.load_X_y()
Webspam.get_y()
# %store Webspam

from efficient_probit_regression.datasets import KDDCup
KDDCup = KDDCup()
KDDCup.load_X_y()
KDDCup.get_y()
# %store KDDCup

from efficient_probit_regression.datasets import Iris
Iris = Iris()
Iris.load_X_y()
Iris.get_y()
# %store Iris

from efficient_probit_regression.datasets import Example2D
Example2D = Example2D()
Example2D.load_X_y()
Example2D.get_y()
# %store Example2D

from efficient_probit_regression.datasets import Covertype
Covertype = Covertype()
Covertype.load_X_y()
Covertype.get_y()
# %store Covertype
# Out:
# 2026-04-13 18:51:01,358 - PID: 24960 - PName: MainProcess - INFO - Downloading data from https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/webspam_wc_normalized_unigram.svm.xz
# 2026-04-13 18:51:47,871 - PID: 24960 - PName: MainProcess - INFO - Download completed.
# 2026-04-13 18:51:47,872 - PID: 24960 - PName: MainProcess - INFO - Extracting data...
# 2026-04-13 18:51:57,424 - PID: 24960 - PName: MainProcess - INFO - Writing .csv file to C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\webspam.csv
# 2026-04-13 18:52:18,737 - PID: 24960 - PName: MainProcess - INFO - Preprocessing the data...
# 2026-04-13 18:52:20,333 - PID: 24960 - PName: MainProcess - INFO - Loading X and y...
# 2026-04-13 18:52:22,614 - PID: 24960 - PName: MainProcess - INFO - Preprocessing the data...
# 2026-04-13 18:52:24,181 - PID: 24960 - PName: MainProcess - INFO - Done.
# 2026-04-13 18:52:24,344 - PID: 24960 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\webspam_X.npy and C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\webspam_y.npy.
# 2026-04-13 18:52:25,575 - PID: 24960 - PName: MainProcess - INFO - Fetching kddcup from sklearn...
# Stored 'Webspam' (Webspam)
# 2026-04-13 18:52:26,214 - PID: 24960 - PName: MainProcess - INFO - Preprocessing...
# C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.venv\Lib\site-packages\sklearn\preprocessing\_data.py:273: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# 2026-04-13 18:52:26,840 - PID: 24960 - PName: MainProcess - INFO - Loading X and y...
# 2026-04-13 18:52:26,840 - PID: 24960 - PName: MainProcess - INFO - Fetching kddcup from sklearn...
# 2026-04-13 18:52:27,403 - PID: 24960 - PName: MainProcess - INFO - Preprocessing...
# C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.venv\Lib\site-packages\sklearn\preprocessing\_data.py:273: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# 2026-04-13 18:52:28,017 - PID: 24960 - PName: MainProcess - INFO - Done.
# 2026-04-13 18:52:28,081 - PID: 24960 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\kddcup_X.npy and C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\kddcup_y.npy.
# 2026-04-13 18:52:28,358 - PID: 24960 - PName: MainProcess - INFO - Loading X and y...
# 2026-04-13 18:52:28,359 - PID: 24960 - PName: MainProcess - INFO - Done.
# 2026-04-13 18:52:28,361 - PID: 24960 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\iris_X.npy and C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\iris_y.npy.
# 2026-04-13 18:52:28,362 - PID: 24960 - PName: MainProcess - INFO - Loading X and y...
# 2026-04-13 18:52:28,363 - PID: 24960 - PName: MainProcess - INFO - Done.
# 2026-04-13 18:52:28,364 - PID: 24960 - PName: MainProcess - INFO - Fetching covertype from sklearn...
# 2026-04-13 18:52:28,510 - PID: 24960 - PName: MainProcess - INFO - Preprocessing...
# Stored 'KDDCup' (KDDCup)
# Stored 'Iris' (Iris)
# Stored 'Example2D' (Example2D)
# 2026-04-13 18:52:28,741 - PID: 24960 - PName: MainProcess - INFO - Loading X and y...
# 2026-04-13 18:52:28,741 - PID: 24960 - PName: MainProcess - INFO - Fetching covertype from sklearn...
# 2026-04-13 18:52:28,874 - PID: 24960 - PName: MainProcess - INFO - Preprocessing...
# 2026-04-13 18:52:29,108 - PID: 24960 - PName: MainProcess - INFO - Done.
# 2026-04-13 18:52:29,216 - PID: 24960 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\covertype_X.npy and C:\Users\Hanji\PycharmProjects\Bachelorarbeit\.data-cache\covertype_y.npy.
# Stored 'Covertype' (Covertype)

# %%
# load all datasets

# %store -r Webspam
# %store -r Iris
# %store -r KDDCup
# %store -r Covertype
# %store -r Example2D

# %%
# check the dimensions of the datasets, they have to be 2D

print("Covertype dimension:", len(Covertype.X.shape))
print("Example2D dimension:", len(Example2D.X.shape))
print("Iris dimension:", len(Iris.X.shape))
print("KDDCup dimension:", len(KDDCup.X.shape))
print("Webspam dimension:", len(Webspam.X.shape))
# Out:
# Covertype dimension: 2
# Example2D dimension: 2
# Iris dimension: 2
# KDDCup dimension: 2
# Webspam dimension: 2
