# %%
# load and save all datasets

from efficient_probit_regression.datasets import Webspam
Webspam = Webspam()
Webspam.download_dataset()
Webspam.load_X_y()
Webspam.get_y()
# %store Webspam

from efficient_probit_regression.datasets import KDDCup
KDDCup = KDDCup()
KDDCup.load_X_y()
KDDCup.get_y()
# %store KDDCup

from efficient_probit_regression.datasets import Iris
Iris = Iris()
Iris.load_X_y()
Iris.get_y()
# %store Iris

from efficient_probit_regression.datasets import Example2D
Example2D = Example2D()
Example2D.load_X_y()
Example2D.get_y()
# %store Example2D

from efficient_probit_regression.datasets import Covertype
Covertype = Covertype()
Covertype.load_X_y()
Covertype.get_y()
# %store Covertype
# Out:
# 2026-02-12 22:08:45,159 - PID: 27292 - PName: MainProcess - INFO - Downloading data from https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary/webspam_wc_normalized_unigram.svm.xz
# 2026-02-12 22:09:23,699 - PID: 27292 - PName: MainProcess - INFO - Download completed.
# 2026-02-12 22:09:23,700 - PID: 27292 - PName: MainProcess - INFO - Extracting data...
# 2026-02-12 22:09:33,575 - PID: 27292 - PName: MainProcess - INFO - Writing .csv file to C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\webspam.csv
# 2026-02-12 22:09:55,233 - PID: 27292 - PName: MainProcess - INFO - Preprocessing the data...
# 2026-02-12 22:09:56,806 - PID: 27292 - PName: MainProcess - INFO - Loading X and y...
# 2026-02-12 22:09:59,212 - PID: 27292 - PName: MainProcess - INFO - Preprocessing the data...
# 2026-02-12 22:10:00,766 - PID: 27292 - PName: MainProcess - INFO - Done.
# 2026-02-12 22:10:00,955 - PID: 27292 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\webspam_X.npy and C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\webspam_y.npy.
# 2026-02-12 22:10:02,199 - PID: 27292 - PName: MainProcess - INFO - Fetching kddcup from sklearn...
# Stored 'Webspam' (Webspam)
# 2026-02-12 22:10:02,793 - PID: 27292 - PName: MainProcess - INFO - Preprocessing...
# C:\Users\Hanji\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\preprocessing\_data.py:273: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# 2026-02-12 22:10:03,408 - PID: 27292 - PName: MainProcess - INFO - Loading X and y...
# 2026-02-12 22:10:03,409 - PID: 27292 - PName: MainProcess - INFO - Fetching kddcup from sklearn...
# 2026-02-12 22:10:03,969 - PID: 27292 - PName: MainProcess - INFO - Preprocessing...
# C:\Users\Hanji\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\preprocessing\_data.py:273: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# 2026-02-12 22:10:04,569 - PID: 27292 - PName: MainProcess - INFO - Done.
# 2026-02-12 22:10:04,635 - PID: 27292 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\kddcup_X.npy and C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\kddcup_y.npy.
# 2026-02-12 22:10:04,941 - PID: 27292 - PName: MainProcess - INFO - Loading X and y...
# 2026-02-12 22:10:04,943 - PID: 27292 - PName: MainProcess - INFO - Done.
# 2026-02-12 22:10:04,944 - PID: 27292 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\iris_X.npy and C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\iris_y.npy.
# 2026-02-12 22:10:04,946 - PID: 27292 - PName: MainProcess - INFO - Loading X and y...
# 2026-02-12 22:10:04,946 - PID: 27292 - PName: MainProcess - INFO - Done.
# 2026-02-12 22:10:04,947 - PID: 27292 - PName: MainProcess - INFO - Fetching covertype from sklearn...
# 2026-02-12 22:10:05,103 - PID: 27292 - PName: MainProcess - INFO - Preprocessing...
# Stored 'KDDCup' (KDDCup)
# Stored 'Iris' (Iris)
# Stored 'Example2D' (Example2D)
# 2026-02-12 22:10:05,333 - PID: 27292 - PName: MainProcess - INFO - Loading X and y...
# 2026-02-12 22:10:05,334 - PID: 27292 - PName: MainProcess - INFO - Fetching covertype from sklearn...
# 2026-02-12 22:10:05,466 - PID: 27292 - PName: MainProcess - INFO - Preprocessing...
# 2026-02-12 22:10:05,690 - PID: 27292 - PName: MainProcess - INFO - Done.
# 2026-02-12 22:10:05,826 - PID: 27292 - PName: MainProcess - INFO - Saved X and y at C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\covertype_X.npy and C:\Users\Hanji\OneDrive\Documents\GitHub\Bachelorarbeit_Test\.data-cache\covertype_y.npy.
# Stored 'Covertype' (Covertype)

# %%
# load all datasets

# %store -r Webspam
# %store -r Iris
# %store -r KDDCup
# %store -r Covertype
# %store -r Example2D

# %%
# check the dimensions of the datasets, they have to be 2D

print("Covertype dimension:", len(Covertype.X.shape))
print("Example2D dimension:", len(Example2D.X.shape))
print("Iris dimension:", len(Iris.X.shape))
print("KDDCup dimension:", len(KDDCup.X.shape))
print("Webspam dimension:", len(Webspam.X.shape))
# Out:
# Covertype dimension: 2
# Example2D dimension: 2
# Iris dimension: 2
# KDDCup dimension: 2
# Webspam dimension: 2
